# %% [markdown]
# # Fetch & Clone Repo
# Clone the image-tagging-tools repo as it has all the required utils and codes from preprocessing the image datasets to training the models and using them to classify the images.

# %%
#Clone Repo and Change Working Directory
# !git clone https://github.com/kk-digital/kcg-ml
# %cd kcg-ml
# Out:
# Cloning into 'kcg-ml'...
# remote: Enumerating objects: 2506, done.
# remote: Counting objects: 100% (498/498), done.
# remote: Compressing objects: 100% (213/213), done.
# remote: Total 2506 (delta 301), reused 435 (delta 283), pack-reused 2008
# Receiving objects: 100% (2506/2506), 24.91 MiB | 28.15 MiB/s, done.
# Resolving deltas: 100% (1443/1443), done.
# /kaggle/working/kcg-ml

# %% [markdown]
# # Computing Platform Check GPU (CUDA) or CPU / Environment

# %%
#Check Environment And Cuda Version 
from utility.CheckCuda import GetCuda
from utility.envchecker import GetEnvironment

GetCuda()
GetEnvironment()
# Out:
# CUDA version: 11.3
# Environment is kaggle
# CUDA version: 11.3
# 'kaggle'

# %% [markdown]
# # Getting Dataset from Mega

# %% [markdown]
# ### Mega CMD Installation

# %%
#USE it for update the package lists and  then installing the package
# !sudo apt-get update

# %%
# Mega CMD Requirements
# !apt install libmms0 libc-ares2 libc6 libcrypto++6 libgcc1 libmediainfo0v5 libpcre3 libpcrecpp0v5 libssl1.1 libstdc++6 libzen0v5 zlib1g apt-transport-https -y
# !apt --fix-broken install -y

# Mega CMD Download and Installation
# !wget https://mega.nz/linux/MEGAsync/xUbuntu_18.04/amd64/megacmd-xUbuntu_18.04_amd64.deb 
# !sudo dpkg -i megacmd-xUbuntu_18.04_amd64.deb
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libc6 is already the newest version (2.31-0ubuntu9.9).
# libpcre3 is already the newest version (2:8.39-12ubuntu0.1).
# libstdc++6 is already the newest version (10.3.0-1ubuntu1~20.04).
# zlib1g is already the newest version (1:1.2.11.dfsg-2ubuntu1.5).
# apt-transport-https is already the newest version (2.0.9).
# You might want to run 'apt --fix-broken install' to correct these.
# The following packages have unmet dependencies:
#  libmediainfo0v5 : Depends: libtinyxml2-6a (>= 5.0.0) but it is not going to be installed
# E: Unmet dependencies. Try 'apt --fix-broken install' with no packages (or specify a solution).
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Correcting dependencies... Done
# The following additional packages will be installed:
#   libc-ares2 libcrypto++6 libmediainfo0v5 libmms0 libpcrecpp0v5 libtinyxml2-6a
#   libzen0v5
# The following NEW packages will be installed:
#   libc-ares2 libcrypto++6 libmediainfo0v5 libmms0 libpcrecpp0v5 libtinyxml2-6a
#   libzen0v5
# 0 upgraded, 7 newly installed, 0 to remove and 68 not upgraded.
# 1 not fully installed or removed.
# Need to get 3243 kB of archives.
# After this operation, 12.4 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libc-ares2 amd64 1.15.0-1ubuntu0.2 [36.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libcrypto++6 amd64 5.6.4-9build1 [889 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 libmms0 amd64 0.6.4-3 [27.3 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 libtinyxml2-6a amd64 7.0.0+dfsg-1build1 [28.4 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/universe amd64 libzen0v5 amd64 0.4.37-1build1 [97.8 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/universe amd64 libmediainfo0v5 amd64 19.09+dfsg-2build1 [2149 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpcrecpp0v5 amd64 2:8.39-12ubuntu0.1 [15.5 kB]
# Fetched 3243 kB in 0s (8840 kB/s)
#
# 78Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 111594 files and directories currently installed.)
# Preparing to unpack .../0-libc-ares2_1.15.0-1ubuntu0.2_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  3%] [#.........................................................] 8Unpacking libc-ares2:amd64 (1.15.0-1ubuntu0.2) ...
# 7Progress: [  6%] [###.......................................................] 8Selecting previously unselected package libcrypto++6.
# Preparing to unpack .../1-libcrypto++6_5.6.4-9build1_amd64.deb ...
# 7Progress: [ 10%] [#####.....................................................] 8Unpacking libcrypto++6 (5.6.4-9build1) ...
# 7Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package libmms0:amd64.
# Preparing to unpack .../2-libmms0_0.6.4-3_amd64.deb ...
# 7Progress: [ 16%] [#########.................................................] 8Unpacking libmms0:amd64 (0.6.4-3) ...
# 7Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package libtinyxml2-6a:amd64.
# Preparing to unpack .../3-libtinyxml2-6a_7.0.0+dfsg-1build1_amd64.deb ...
# 7Progress: [ 23%] [#############.............................................] 8Unpacking libtinyxml2-6a:amd64 (7.0.0+dfsg-1build1) ...
# 7Progress: [ 26%] [##############............................................] 8Selecting previously unselected package libzen0v5:amd64.
# Preparing to unpack .../4-libzen0v5_0.4.37-1build1_amd64.deb ...
# 7Progress: [ 29%] [################..........................................] 8Unpacking libzen0v5:amd64 (0.4.37-1build1) ...
# 7Progress: [ 32%] [##################........................................] 8Selecting previously unselected package libmediainfo0v5:amd64.
# Preparing to unpack .../5-libmediainfo0v5_19.09+dfsg-2build1_amd64.deb ...
# 7Progress: [ 35%] [####################......................................] 8Unpacking libmediainfo0v5:amd64 (19.09+dfsg-2build1) ...
# 7Progress: [ 39%] [######################....................................] 8Selecting previously unselected package libpcrecpp0v5:amd64.
# Preparing to unpack .../6-libpcrecpp0v5_2%3a8.39-12ubuntu0.1_amd64.deb ...
# 7Progress: [ 42%] [########################..................................] 8Unpacking libpcrecpp0v5:amd64 (2:8.39-12ubuntu0.1) ...
# 7Progress: [ 45%] [##########################................................] 8Setting up libpcrecpp0v5:amd64 (2:8.39-12ubuntu0.1) ...
# 7Progress: [ 48%] [############################..............................] 87Progress: [ 52%] [#############################.............................] 8Setting up libtinyxml2-6a:amd64 (7.0.0+dfsg-1build1) ...
# 7Progress: [ 55%] [###############################...........................] 87Progress: [ 58%] [#################################.........................] 8Setting up libc-ares2:amd64 (1.15.0-1ubuntu0.2) ...
# 7Progress: [ 61%] [###################################.......................] 87Progress: [ 65%] [#####################################.....................] 8Setting up libmms0:amd64 (0.6.4-3) ...
# 7Progress: [ 68%] [#######################################...................] 87Progress: [ 71%] [#########################################.................] 8Setting up libzen0v5:amd64 (0.4.37-1build1) ...
# 7Progress: [ 74%] [###########################################...............] 87Progress: [ 77%] [############################################..............] 8Setting up libmediainfo0v5:amd64 (19.09+dfsg-2build1) ...
# 7Progress: [ 81%] [##############################################............] 87Progress: [ 84%] [################################################..........] 8Setting up libcrypto++6 (5.6.4-9build1) ...
# 7Progress: [ 87%] [##################################################........] 87Progress: [ 90%] [####################################################......] 8Setting up megacmd (1.5.1-1.1) ...
# 7Progress: [ 94%] [######################################################....] 8cat: /usr/share/doc/megacmd/distro: No such file or directory
# cat: /usr/share/doc/megacmd/version: No such file or directory
# sysctl: setting key "fs.inotify.max_user_watches", ignoring: Read-only file system
# 7Progress: [ 97%] [########################################################..] 8Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
#
# 78--2023-03-18 11:48:38--  https://mega.nz/linux/MEGAsync/xUbuntu_18.04/amd64/megacmd-xUbuntu_18.04_amd64.deb
# Resolving mega.nz (mega.nz)... 31.216.145.5, 31.216.144.5, 2a0b:e46:1:145::5, ...
# Connecting to mega.nz (mega.nz)|31.216.145.5|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7434374 (7.1M) [application/x-deb]
# Saving to: ‘megacmd-xUbuntu_18.04_amd64.deb.1’
#
# megacmd-xUbuntu_18. 100%[===================>]   7.09M  5.95MB/s    in 1.2s
#
# 2023-03-18 11:48:39 (5.95 MB/s) - ‘megacmd-xUbuntu_18.04_amd64.deb.1’ saved [7434374/7434374]
#
# (Reading database ... 111635 files and directories currently installed.)
# Preparing to unpack megacmd-xUbuntu_18.04_amd64.deb ...
# Unpacking megacmd (1.5.1-1.1) over (1.5.1-1.1) ...
# Setting up megacmd (1.5.1-1.1) ...
# cat: /usr/share/doc/megacmd/distro: No such file or directory
# cat: /usr/share/doc/megacmd/version: No such file or directory
# sysctl: setting key "fs.inotify.max_user_watches", ignoring: Read-only file system

# %%
# !sudo apt-get update
# Out:
# Get:1 http://packages.cloud.google.com/apt gcsfuse-focal InRelease [5002 B]
# Get:2 https://packages.cloud.google.com/apt cloud-sdk InRelease [6361 B]
# Get:3 https://packages.cloud.google.com/apt google-fast-socket InRelease [5015 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1581 B]
# Hit:5 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:7 http://packages.cloud.google.com/apt gcsfuse-focal/main amd64 Packages [2084 B]
# Get:8 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:9 https://packages.cloud.google.com/apt cloud-sdk/main amd64 Packages [408 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:11 https://packages.cloud.google.com/apt google-fast-socket/main amd64 Packages [429 B]
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [920 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1313 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [2136 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [31.2 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3021 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [28.6 kB]
# Get:18 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [1998 kB]
# Get:19 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2544 kB]
# Get:20 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1017 kB]
# Fetched 13.8 MB in 2s (5617 kB/s)
# Reading package lists... Done

# %% [markdown]
# ### Download Dataset
# Set download URL in Mega and destination path (in Google Drive or session storage) and download the file.

# %%
import os
import contextlib
from subprocess import Popen, PIPE, STDOUT

# Download URL on Mega
tagged_dataset_url = 'https://mega.nz/file/8RhFRISJ#vlQhjBp5hrNtQzFnRVQtD_ilHfIyLOSrlwVXEb3t1UM'
other_dataset_url  = 'https://mega.nz/file/5FhGkRjD#yFihfhr1RMHfPTffhPB4tQtJsnn_HBYFOSfqdPOrp78'
# Destination path for download
destination_path = './downloads'
os.makedirs(destination_path, exist_ok=True)

# Function for printing the download progress
def print_progress(proc, stream='stdout'):
  newlines = ['\n', '\r\n', '\r']
  stream = getattr(proc, stream)
  with contextlib.closing(stream):
      while True:
          out = []
          last = stream.read(1)
          # Don't loop forever
          if last == '' and proc.poll() is not None:
              break
          while last not in newlines:
              # Don't loop forever
              if last == '' and proc.poll() is not None:
                  break
              out.append(last)
              last = stream.read(1)
          out = ''.join(out)
          yield out

# Download dataset
for data_url in [tagged_dataset_url, other_dataset_url]:
  cmd = ["mega-get", data_url, destination_path]
  proc = Popen(cmd,stdout=PIPE, stderr=STDOUT, universal_newlines=True)
  for line in print_progress(proc):
    print(line)
# Out:
# [Initiating MEGAcmd server in background. Log: /root/.megaCmd/megacmdserver.log]
# TRANSFERRING ||#.........................................||(5/929 MB:   0.64 %)
# TRANSFERRING ||##.......................................||(31/929 MB:   3.40 %)
# TRANSFERRING ||##.......................................||(43/929 MB:   4.63 %)
# TRANSFERRING ||##.......................................||(42/929 MB:   4.52 %)
# TRANSFERRING ||##.......................................||(31/929 MB:   3.39 %)
# TRANSFERRING ||###......................................||(63/929 MB:   6.83 %)
# TRANSFERRING ||###......................................||(63/929 MB:   6.83 %)
# TRANSFERRING ||###......................................||(64/929 MB:   6.94 %)
# TRANSFERRING ||####.....................................||(71/929 MB:   7.70 %)
# TRANSFERRING ||####.....................................||(84/929 MB:   9.05 %)
# TRANSFERRING ||####.....................................||(85/929 MB:   9.23 %)
# TRANSFERRING ||#####...................................||(100/929 MB:  10.83 %)
# TRANSFERRING ||######..................................||(125/929 MB:  13.50 %)
# TRANSFERRING ||######..................................||(127/929 MB:  13.71 %)
# TRANSFERRING ||######..................................||(127/929 MB:  13.71 %)
# TRANSFERRING ||######..................................||(131/929 MB:  14.15 %)
# TRANSFERRING ||######..................................||(139/929 MB:  14.96 %)
# TRANSFERRING ||#######.................................||(155/929 MB:  16.74 %)
# TRANSFERRING ||########................................||(174/929 MB:  18.77 %)
# TRANSFERRING ||#######.................................||(156/929 MB:  16.83 %)
# TRANSFERRING ||#########...............................||(191/929 MB:  20.60 %)
# TRANSFERRING ||#########...............................||(191/929 MB:  20.60 %)
# TRANSFERRING ||#########...............................||(193/929 MB:  20.81 %)
# TRANSFERRING ||#########...............................||(200/929 MB:  21.56 %)
# TRANSFERRING ||##########..............................||(212/929 MB:  22.90 %)
# TRANSFERRING ||##########..............................||(223/929 MB:  24.04 %)
# TRANSFERRING ||##########..............................||(219/929 MB:  23.59 %)
# TRANSFERRING ||###########.............................||(244/929 MB:  26.29 %)
# TRANSFERRING ||###########.............................||(254/929 MB:  27.35 %)
# TRANSFERRING ||###########.............................||(255/929 MB:  27.48 %)
# TRANSFERRING ||###########.............................||(255/929 MB:  27.48 %)
# TRANSFERRING ||############............................||(261/929 MB:  28.10 %)
# TRANSFERRING ||############............................||(262/929 MB:  28.29 %)
# TRANSFERRING ||############............................||(273/929 MB:  29.44 %)
# TRANSFERRING ||############............................||(274/929 MB:  29.50 %)
# TRANSFERRING ||##############..........................||(302/929 MB:  32.57 %)
# TRANSFERRING ||##############..........................||(316/929 MB:  34.07 %)
# TRANSFERRING ||##############..........................||(303/929 MB:  32.64 %)
# TRANSFERRING ||##############..........................||(323/929 MB:  34.82 %)
# TRANSFERRING ||###############.........................||(329/929 MB:  35.46 %)
# TRANSFERRING ||###############.........................||(337/929 MB:  36.30 %)
# TRANSFERRING ||###############.........................||(348/929 MB:  37.48 %)
# TRANSFERRING ||################........................||(363/929 MB:  39.08 %)
# TRANSFERRING ||################........................||(360/929 MB:  38.72 %)
# TRANSFERRING ||################........................||(364/929 MB:  39.20 %)
# TRANSFERRING ||#################.......................||(374/929 MB:  40.32 %)
# TRANSFERRING ||##################......................||(398/929 MB:  42.84 %)
# TRANSFERRING ||#################.......................||(383/929 MB:  41.25 %)
# TRANSFERRING ||##################......................||(402/929 MB:  43.32 %)
# TRANSFERRING ||##################......................||(412/929 MB:  44.32 %)
# TRANSFERRING ||###################.....................||(425/929 MB:  45.79 %)
# TRANSFERRING ||###################.....................||(437/929 MB:  47.02 %)
# TRANSFERRING ||###################.....................||(428/929 MB:  46.11 %)
# TRANSFERRING ||###################.....................||(432/929 MB:  46.47 %)
# TRANSFERRING ||####################....................||(448/929 MB:  48.26 %)
# TRANSFERRING ||####################....................||(449/929 MB:  48.39 %)
# TRANSFERRING ||####################....................||(457/929 MB:  49.20 %)
# TRANSFERRING ||#####################...................||(471/929 MB:  50.68 %)
# TRANSFERRING ||#####################...................||(467/929 MB:  50.25 %)
# TRANSFERRING ||######################..................||(494/929 MB:  53.22 %)
# TRANSFERRING ||######################..................||(505/929 MB:  54.36 %)
# TRANSFERRING ||#######################.................||(511/929 MB:  55.01 %)
# TRANSFERRING ||#######################.................||(511/929 MB:  55.01 %)
# TRANSFERRING ||#######################.................||(515/929 MB:  55.43 %)
# TRANSFERRING ||#######################.................||(526/929 MB:  56.60 %)
# TRANSFERRING ||########################................||(536/929 MB:  57.67 %)
# TRANSFERRING ||########################................||(535/929 MB:  57.60 %)
# TRANSFERRING ||#########################...............||(566/929 MB:  60.92 %)
# TRANSFERRING ||#########################...............||(559/929 MB:  60.17 %)
# TRANSFERRING ||#########################...............||(575/929 MB:  61.90 %)
# TRANSFERRING ||##########################..............||(582/929 MB:  62.64 %)
# TRANSFERRING ||##########################..............||(592/929 MB:  63.73 %)
# TRANSFERRING ||###########################.............||(608/929 MB:  65.45 %)
# TRANSFERRING ||###########################.............||(623/929 MB:  67.04 %)
# TRANSFERRING ||############################............||(633/929 MB:  68.13 %)
# TRANSFERRING ||###########################.............||(623/929 MB:  67.06 %)
# TRANSFERRING ||############################............||(639/929 MB:  68.78 %)
# TRANSFERRING ||############################............||(642/929 MB:  69.09 %)
# TRANSFERRING ||#############################...........||(651/929 MB:  70.03 %)
# TRANSFERRING ||############################............||(648/929 MB:  69.73 %)
# TRANSFERRING ||##############################..........||(674/929 MB:  72.59 %)
# TRANSFERRING ||##############################..........||(687/929 MB:  73.93 %)
# TRANSFERRING ||##############################..........||(696/929 MB:  74.96 %)
# TRANSFERRING ||#############################...........||(672/929 MB:  72.32 %)
# TRANSFERRING ||##############################..........||(691/929 MB:  74.39 %)
# TRANSFERRING ||###############################.........||(712/929 MB:  76.65 %)
# TRANSFERRING ||################################........||(721/929 MB:  77.57 %)
# TRANSFERRING ||###############################.........||(712/929 MB:  76.62 %)
# TRANSFERRING ||################################........||(732/929 MB:  78.83 %)
# TRANSFERRING ||################################........||(727/929 MB:  78.22 %)
# TRANSFERRING ||#################################.......||(750/929 MB:  80.73 %)
# TRANSFERRING ||#################################.......||(762/929 MB:  82.00 %)
# TRANSFERRING ||#################################.......||(757/929 MB:  81.46 %)
# TRANSFERRING ||##################################......||(781/929 MB:  84.04 %)
# TRANSFERRING ||###################################.....||(790/929 MB:  85.01 %)
# TRANSFERRING ||###################################.....||(796/929 MB:  85.68 %)
# TRANSFERRING ||##################################......||(789/929 MB:  84.96 %)
# TRANSFERRING ||####################################....||(817/929 MB:  87.95 %)
# TRANSFERRING ||####################################....||(827/929 MB:  88.97 %)
# TRANSFERRING ||#####################################...||(839/929 MB:  90.25 %)
# TRANSFERRING ||#####################################...||(845/929 MB:  90.89 %)
# TRANSFERRING ||#####################################...||(837/929 MB:  90.03 %)
# TRANSFERRING ||#####################################...||(858/929 MB:  92.38 %)
# TRANSFERRING ||######################################..||(863/929 MB:  92.87 %)
# TRANSFERRING ||######################################..||(864/929 MB:  92.93 %)
# TRANSFERRING ||######################################..||(870/929 MB:  93.58 %)
# TRANSFERRING ||######################################..||(875/929 MB:  94.21 %)
# TRANSFERRING ||######################################..||(879/929 MB:  94.59 %)
# TRANSFERRING ||#######################################.||(892/929 MB:  96.00 %)
# TRANSFERRING ||#######################################.||(895/929 MB:  96.31 %)
# TRANSFERRING ||#######################################.||(896/929 MB:  96.42 %)
# TRANSFERRING ||#######################################.||(897/929 MB:  96.52 %)
# TRANSFERRING ||#######################################.||(904/929 MB:  97.30 %)
# TRANSFERRING ||########################################||(911/929 MB:  98.03 %)
# TRANSFERRING ||########################################||(911/929 MB:  98.03 %)
# TRANSFERRING ||########################################||(914/929 MB:  98.40 %)
# TRANSFERRING ||########################################||(916/929 MB:  98.60 %)
# TRANSFERRING ||########################################||(919/929 MB:  98.89 %)
# TRANSFERRING ||########################################||(921/929 MB:  99.11 %)
# TRANSFERRING ||########################################||(922/929 MB:  99.22 %)
# TRANSFERRING ||########################################||(925/929 MB:  99.54 %)
# TRANSFERRING ||########################################||(926/929 MB:  99.64 %)
# TRANSFERRING ||########################################||(927/929 MB:  99.70 %)
# TRANSFERRING ||########################################||(929/929 MB:  99.97 %)
# TRANSFERRING ||########################################||(929/929 MB: 100.00 %)
# Download finished: /kaggle/working/kcg-ml/./downloads/pixel-art-tagged-v3.zip
# TRANSFERRING ||########################################||(929/929 MB: 100.00 %)
# TRANSFERRING ||#.........................................||(1/987 MB:   0.12 %)
# TRANSFERRING ||#.........................................||(1/987 MB:   0.17 %)
# TRANSFERRING ||#.........................................||(2/987 MB:   0.26 %)
# TRANSFERRING ||#.........................................||(3/987 MB:   0.35 %)
# TRANSFERRING ||#.........................................||(4/987 MB:   0.50 %)
# TRANSFERRING ||#.........................................||(6/987 MB:   0.64 %)
# TRANSFERRING ||#.........................................||(8/987 MB:   0.90 %)
# TRANSFERRING ||#........................................||(11/987 MB:   1.17 %)
# TRANSFERRING ||#........................................||(15/987 MB:   1.61 %)
# TRANSFERRING ||#........................................||(21/987 MB:   2.17 %)
# TRANSFERRING ||##.......................................||(28/987 MB:   2.89 %)
# TRANSFERRING ||##.......................................||(36/987 MB:   3.70 %)
# TRANSFERRING ||##.......................................||(44/987 MB:   4.53 %)
# TRANSFERRING ||##.......................................||(34/987 MB:   3.47 %)
# TRANSFERRING ||#........................................||(18/987 MB:   1.91 %)
# TRANSFERRING ||###......................................||(50/987 MB:   5.11 %)
# TRANSFERRING ||###......................................||(52/987 MB:   5.30 %)
# TRANSFERRING ||###......................................||(57/987 MB:   5.82 %)
# TRANSFERRING ||###......................................||(62/987 MB:   6.33 %)
# TRANSFERRING ||###......................................||(66/987 MB:   6.73 %)
# TRANSFERRING ||###......................................||(68/987 MB:   6.95 %)
# TRANSFERRING ||###......................................||(71/987 MB:   7.24 %)
# TRANSFERRING ||####.....................................||(74/987 MB:   7.56 %)
# TRANSFERRING ||####.....................................||(78/987 MB:   7.98 %)
# TRANSFERRING ||###......................................||(66/987 MB:   6.71 %)
# TRANSFERRING ||###......................................||(69/987 MB:   7.06 %)
# TRANSFERRING ||####.....................................||(88/987 MB:   8.94 %)
# TRANSFERRING ||####.....................................||(91/987 MB:   9.26 %)
# TRANSFERRING ||####.....................................||(94/987 MB:   9.58 %)
# TRANSFERRING ||#####....................................||(97/987 MB:   9.85 %)
# TRANSFERRING ||#####...................................||(100/987 MB:  10.13 %)
# TRANSFERRING ||#####...................................||(102/987 MB:  10.40 %)
# TRANSFERRING ||#####...................................||(105/987 MB:  10.68 %)
# TRANSFERRING ||#####...................................||(108/987 MB:  10.94 %)
# TRANSFERRING ||#####...................................||(111/987 MB:  11.34 %)
# TRANSFERRING ||#####....................................||(99/987 MB:  10.04 %)
# TRANSFERRING ||#####...................................||(117/987 MB:  11.91 %)
# TRANSFERRING ||#####...................................||(120/987 MB:  12.17 %)
# TRANSFERRING ||#####...................................||(122/987 MB:  12.39 %)
# TRANSFERRING ||######..................................||(124/987 MB:  12.56 %)
# TRANSFERRING ||######..................................||(125/987 MB:  12.69 %)
# TRANSFERRING ||######..................................||(126/987 MB:  12.78 %)
# TRANSFERRING ||######..................................||(127/987 MB:  12.87 %)
# TRANSFERRING ||######..................................||(128/987 MB:  12.97 %)
# TRANSFERRING ||######..................................||(128/987 MB:  13.05 %)
# TRANSFERRING ||######..................................||(130/987 MB:  13.20 %)
# TRANSFERRING ||######..................................||(133/987 MB:  13.50 %)
# TRANSFERRING ||######..................................||(137/987 MB:  13.92 %)
# TRANSFERRING ||######..................................||(141/987 MB:  14.30 %)
# TRANSFERRING ||#################.......................||(405/987 MB:  41.09 %)
# TRANSFERRING ||#################.......................||(407/987 MB:  41.22 %)
# TRANSFERRING ||#################.......................||(408/987 MB:  41.34 %)
# TRANSFERRING ||#################.......................||(409/987 MB:  41.46 %)
# TRANSFERRING ||#################.......................||(410/987 MB:  41.58 %)
# TRANSFERRING ||#################.......................||(411/987 MB:  41.69 %)
# TRANSFERRING ||#################.......................||(412/987 MB:  41.78 %)
# TRANSFERRING ||#################.......................||(413/987 MB:  41.86 %)
# TRANSFERRING ||#################.......................||(414/987 MB:  41.96 %)
# TRANSFERRING ||#################.......................||(415/987 MB:  42.03 %)
# TRANSFERRING ||#################.......................||(415/987 MB:  42.11 %)
# TRANSFERRING ||#################.......................||(416/987 MB:  42.19 %)
# TRANSFERRING ||#################.......................||(417/987 MB:  42.29 %)
# TRANSFERRING ||#################.......................||(418/987 MB:  42.36 %)
# TRANSFERRING ||#################.......................||(419/987 MB:  42.45 %)
# TRANSFERRING ||##################......................||(419/987 MB:  42.52 %)
# TRANSFERRING ||##################......................||(420/987 MB:  42.59 %)
# TRANSFERRING ||##################......................||(421/987 MB:  42.67 %)
# TRANSFERRING ||##################......................||(422/987 MB:  42.75 %)
# TRANSFERRING ||##################......................||(422/987 MB:  42.82 %)
# TRANSFERRING ||##################......................||(423/987 MB:  42.90 %)
# TRANSFERRING ||##################......................||(424/987 MB:  42.97 %)
# TRANSFERRING ||##################......................||(424/987 MB:  43.03 %)
# TRANSFERRING ||##################......................||(425/987 MB:  43.09 %)
# TRANSFERRING ||##################......................||(426/987 MB:  43.16 %)
# TRANSFERRING ||##################......................||(426/987 MB:  43.22 %)
# TRANSFERRING ||##################......................||(427/987 MB:  43.28 %)
# TRANSFERRING ||##################......................||(427/987 MB:  43.33 %)
# TRANSFERRING ||##################......................||(428/987 MB:  43.38 %)
# TRANSFERRING ||##################......................||(428/987 MB:  43.44 %)
# TRANSFERRING ||##################......................||(429/987 MB:  43.49 %)
# TRANSFERRING ||##################......................||(429/987 MB:  43.53 %)
# TRANSFERRING ||##################......................||(430/987 MB:  43.59 %)
# TRANSFERRING ||##################......................||(430/987 MB:  43.63 %)
# TRANSFERRING ||##################......................||(431/987 MB:  43.68 %)
# TRANSFERRING ||##################......................||(431/987 MB:  43.72 %)
# TRANSFERRING ||##################......................||(432/987 MB:  43.76 %)
# TRANSFERRING ||##################......................||(432/987 MB:  43.82 %)
# TRANSFERRING ||##################......................||(433/987 MB:  43.87 %)
# TRANSFERRING ||##################......................||(433/987 MB:  43.91 %)
# TRANSFERRING ||##################......................||(434/987 MB:  43.97 %)
# TRANSFERRING ||##################......................||(434/987 MB:  44.02 %)
# TRANSFERRING ||##################......................||(435/987 MB:  44.07 %)
# TRANSFERRING ||##################......................||(435/987 MB:  44.13 %)
# TRANSFERRING ||##################......................||(436/987 MB:  44.17 %)
# TRANSFERRING ||##################......................||(436/987 MB:  44.21 %)
# TRANSFERRING ||##################......................||(436/987 MB:  44.25 %)
# TRANSFERRING ||##################......................||(437/987 MB:  44.29 %)
# TRANSFERRING ||##################......................||(437/987 MB:  44.34 %)
# TRANSFERRING ||##################......................||(438/987 MB:  44.38 %)
# TRANSFERRING ||##################......................||(438/987 MB:  44.42 %)
# TRANSFERRING ||##################......................||(439/987 MB:  44.46 %)
# TRANSFERRING ||##################......................||(439/987 MB:  44.50 %)
# TRANSFERRING ||##################......................||(439/987 MB:  44.54 %)
# TRANSFERRING ||##################......................||(440/987 MB:  44.59 %)
# TRANSFERRING ||##################......................||(440/987 MB:  44.62 %)
# TRANSFERRING ||##################......................||(441/987 MB:  44.66 %)
# TRANSFERRING ||##################......................||(441/987 MB:  44.71 %)
# TRANSFERRING ||##################......................||(441/987 MB:  44.75 %)
# TRANSFERRING ||##################......................||(442/987 MB:  44.78 %)
# TRANSFERRING ||##################......................||(442/987 MB:  44.81 %)
# TRANSFERRING ||##################......................||(442/987 MB:  44.84 %)
# TRANSFERRING ||##################......................||(443/987 MB:  44.88 %)
# TRANSFERRING ||##################......................||(443/987 MB:  44.93 %)
# TRANSFERRING ||##################......................||(444/987 MB:  44.97 %)
# TRANSFERRING ||###################.....................||(444/987 MB:  45.01 %)
# TRANSFERRING ||###################.....................||(444/987 MB:  45.05 %)
# TRANSFERRING ||###################.....................||(445/987 MB:  45.09 %)
# TRANSFERRING ||###################.....................||(445/987 MB:  45.13 %)
# TRANSFERRING ||###################.....................||(446/987 MB:  45.17 %)
# TRANSFERRING ||###################.....................||(446/987 MB:  45.21 %)
# TRANSFERRING ||###################.....................||(446/987 MB:  45.25 %)
# TRANSFERRING ||###################.....................||(447/987 MB:  45.30 %)
# TRANSFERRING ||###################.....................||(447/987 MB:  45.34 %)
# TRANSFERRING ||###################.....................||(448/987 MB:  45.38 %)
# TRANSFERRING ||###################.....................||(448/987 MB:  45.42 %)
# TRANSFERRING ||###################.....................||(448/987 MB:  45.46 %)
# TRANSFERRING ||###################.....................||(449/987 MB:  45.50 %)
# TRANSFERRING ||###################.....................||(449/987 MB:  45.54 %)
# TRANSFERRING ||###################.....................||(450/987 MB:  45.58 %)
# TRANSFERRING ||###################.....................||(450/987 MB:  45.62 %)
# TRANSFERRING ||###################.....................||(451/987 MB:  45.67 %)
# TRANSFERRING ||###################.....................||(451/987 MB:  45.72 %)
# TRANSFERRING ||###################.....................||(451/987 MB:  45.76 %)
# TRANSFERRING ||###################.....................||(452/987 MB:  45.80 %)
# TRANSFERRING ||###################.....................||(452/987 MB:  45.84 %)
# TRANSFERRING ||###################.....................||(453/987 MB:  45.89 %)
# TRANSFERRING ||###################.....................||(453/987 MB:  45.95 %)
# TRANSFERRING ||###################.....................||(454/987 MB:  45.99 %)
# TRANSFERRING ||###################.....................||(454/987 MB:  46.04 %)
# TRANSFERRING ||###################.....................||(455/987 MB:  46.09 %)
# TRANSFERRING ||###################.....................||(455/987 MB:  46.15 %)
# TRANSFERRING ||###################.....................||(456/987 MB:  46.20 %)
# TRANSFERRING ||###################.....................||(456/987 MB:  46.25 %)
# TRANSFERRING ||###################.....................||(457/987 MB:  46.31 %)
# TRANSFERRING ||###################.....................||(457/987 MB:  46.36 %)
# TRANSFERRING ||###################.....................||(458/987 MB:  46.41 %)
# TRANSFERRING ||###################.....................||(458/987 MB:  46.46 %)
# TRANSFERRING ||###################.....................||(459/987 MB:  46.50 %)
# TRANSFERRING ||###################.....................||(459/987 MB:  46.54 %)
# TRANSFERRING ||###################.....................||(460/987 MB:  46.59 %)
# TRANSFERRING ||###################.....................||(460/987 MB:  46.64 %)
# TRANSFERRING ||###################.....................||(460/987 MB:  46.67 %)
# TRANSFERRING ||###################.....................||(461/987 MB:  46.70 %)
# TRANSFERRING ||###################.....................||(461/987 MB:  46.73 %)
# TRANSFERRING ||###################.....................||(461/987 MB:  46.76 %)
# TRANSFERRING ||###################.....................||(462/987 MB:  46.79 %)
# TRANSFERRING ||###################.....................||(462/987 MB:  46.83 %)
# TRANSFERRING ||###################.....................||(462/987 MB:  46.87 %)
# TRANSFERRING ||###################.....................||(463/987 MB:  46.91 %)
# TRANSFERRING ||###################.....................||(463/987 MB:  46.96 %)
# TRANSFERRING ||###################.....................||(464/987 MB:  47.00 %)
# TRANSFERRING ||###################.....................||(464/987 MB:  47.05 %)
# TRANSFERRING ||###################.....................||(465/987 MB:  47.09 %)
# TRANSFERRING ||###################.....................||(465/987 MB:  47.15 %)
# TRANSFERRING ||###################.....................||(466/987 MB:  47.20 %)
# TRANSFERRING ||###################.....................||(466/987 MB:  47.24 %)
# TRANSFERRING ||###################.....................||(466/987 MB:  47.26 %)
# TRANSFERRING ||###################.....................||(467/987 MB:  47.30 %)
# TRANSFERRING ||###################.....................||(467/987 MB:  47.33 %)
# TRANSFERRING ||###################.....................||(467/987 MB:  47.36 %)
# TRANSFERRING ||###################.....................||(468/987 MB:  47.40 %)
# TRANSFERRING ||###################.....................||(468/987 MB:  47.43 %)
# TRANSFERRING ||###################.....................||(468/987 MB:  47.46 %)
# TRANSFERRING ||###################.....................||(468/987 MB:  47.49 %)
# TRANSFERRING ||####################....................||(469/987 MB:  47.52 %)
# TRANSFERRING ||####################....................||(469/987 MB:  47.56 %)
# TRANSFERRING ||####################....................||(469/987 MB:  47.59 %)
# TRANSFERRING ||####################....................||(470/987 MB:  47.63 %)
# TRANSFERRING ||####################....................||(470/987 MB:  47.68 %)
# TRANSFERRING ||####################....................||(471/987 MB:  47.72 %)
# TRANSFERRING ||####################....................||(471/987 MB:  47.77 %)
# TRANSFERRING ||####################....................||(472/987 MB:  47.83 %)
# TRANSFERRING ||####################....................||(472/987 MB:  47.88 %)
# TRANSFERRING ||####################....................||(473/987 MB:  47.94 %)
# TRANSFERRING ||####################....................||(473/987 MB:  48.00 %)
# TRANSFERRING ||####################....................||(474/987 MB:  48.05 %)
# TRANSFERRING ||####################....................||(474/987 MB:  48.09 %)
# TRANSFERRING ||####################....................||(475/987 MB:  48.12 %)
# TRANSFERRING ||####################....................||(475/987 MB:  48.16 %)
# TRANSFERRING ||####################....................||(476/987 MB:  48.20 %)
%)
# TRANSFERRING ||######################################..||(933/987 MB:  94.57 %)
# TRANSFERRING ||######################################..||(934/987 MB:  94.61 %)
# TRANSFERRING ||######################################..||(934/987 MB:  94.66 %)
# TRANSFERRING ||######################################..||(935/987 MB:  94.69 %)
# TRANSFERRING ||######################################..||(935/987 MB:  94.73 %)
# TRANSFERRING ||######################################..||(935/987 MB:  94.76 %)
# TRANSFERRING ||######################################..||(936/987 MB:  94.80 %)
# TRANSFERRING ||######################################..||(936/987 MB:  94.83 %)
# TRANSFERRING ||######################################..||(936/987 MB:  94.86 %)
# TRANSFERRING ||######################################..||(937/987 MB:  94.89 %)
# TRANSFERRING ||######################################..||(937/987 MB:  94.91 %)
# TRANSFERRING ||######################################..||(937/987 MB:  94.95 %)
# TRANSFERRING ||######################################..||(937/987 MB:  94.98 %)
# TRANSFERRING ||#######################################.||(938/987 MB:  95.03 %)
# TRANSFERRING ||#######################################.||(938/987 MB:  95.07 %)
# TRANSFERRING ||#######################################.||(939/987 MB:  95.12 %)
# TRANSFERRING ||#######################################.||(939/987 MB:  95.16 %)
# TRANSFERRING ||#######################################.||(940/987 MB:  95.21 %)
# TRANSFERRING ||#######################################.||(940/987 MB:  95.26 %)
# TRANSFERRING ||#######################################.||(941/987 MB:  95.30 %)
# TRANSFERRING ||#######################################.||(941/987 MB:  95.35 %)
# TRANSFERRING ||#######################################.||(942/987 MB:  95.39 %)
# TRANSFERRING ||#######################################.||(942/987 MB:  95.43 %)
# TRANSFERRING ||#######################################.||(942/987 MB:  95.47 %)
# TRANSFERRING ||#######################################.||(943/987 MB:  95.51 %)
# TRANSFERRING ||#######################################.||(943/987 MB:  95.55 %)
# TRANSFERRING ||#######################################.||(944/987 MB:  95.59 %)
# TRANSFERRING ||#######################################.||(944/987 MB:  95.64 %)
# TRANSFERRING ||#######################################.||(944/987 MB:  95.68 %)
# TRANSFERRING ||#######################################.||(945/987 MB:  95.72 %)
# TRANSFERRING ||#######################################.||(945/987 MB:  95.75 %)
# TRANSFERRING ||#######################################.||(945/987 MB:  95.79 %)
# TRANSFERRING ||#######################################.||(946/987 MB:  95.84 %)
# TRANSFERRING ||#######################################.||(946/987 MB:  95.88 %)
# TRANSFERRING ||#######################################.||(947/987 MB:  95.93 %)
# TRANSFERRING ||#######################################.||(947/987 MB:  95.98 %)
# TRANSFERRING ||#######################################.||(948/987 MB:  96.03 %)
# TRANSFERRING ||#######################################.||(948/987 MB:  96.08 %)
# TRANSFERRING ||#######################################.||(949/987 MB:  96.13 %)
# TRANSFERRING ||#######################################.||(949/987 MB:  96.18 %)
# TRANSFERRING ||#######################################.||(950/987 MB:  96.23 %)
# TRANSFERRING ||#######################################.||(950/987 MB:  96.28 %)
# TRANSFERRING ||#######################################.||(951/987 MB:  96.33 %)
# TRANSFERRING ||#######################################.||(951/987 MB:  96.37 %)
# TRANSFERRING ||#######################################.||(951/987 MB:  96.40 %)
# TRANSFERRING ||#######################################.||(952/987 MB:  96.44 %)
# TRANSFERRING ||#######################################.||(952/987 MB:  96.47 %)
# TRANSFERRING ||#######################################.||(953/987 MB:  96.51 %)
# TRANSFERRING ||#######################################.||(953/987 MB:  96.55 %)
# TRANSFERRING ||#######################################.||(953/987 MB:  96.59 %)
# TRANSFERRING ||#######################################.||(954/987 MB:  96.63 %)
# TRANSFERRING ||#######################################.||(954/987 MB:  96.68 %)
# TRANSFERRING ||#######################################.||(955/987 MB:  96.73 %)
# TRANSFERRING ||#######################################.||(955/987 MB:  96.77 %)
# TRANSFERRING ||#######################################.||(948/987 MB:  96.01 %)
# TRANSFERRING ||#######################################.||(956/987 MB:  96.86 %)
# TRANSFERRING ||#######################################.||(956/987 MB:  96.90 %)
# TRANSFERRING ||#######################################.||(957/987 MB:  96.94 %)
# TRANSFERRING ||#######################################.||(957/987 MB:  96.98 %)
# TRANSFERRING ||#######################################.||(958/987 MB:  97.02 %)
# TRANSFERRING ||#######################################.||(958/987 MB:  97.05 %)
# TRANSFERRING ||#######################################.||(958/987 MB:  97.09 %)
# TRANSFERRING ||#######################################.||(959/987 MB:  97.14 %)
# TRANSFERRING ||#######################################.||(959/987 MB:  97.19 %)
# TRANSFERRING ||#######################################.||(960/987 MB:  97.23 %)
# TRANSFERRING ||#######################################.||(960/987 MB:  97.28 %)
# TRANSFERRING ||#######################################.||(961/987 MB:  97.32 %)
# TRANSFERRING ||#######################################.||(961/987 MB:  97.37 %)
# TRANSFERRING ||#######################################.||(962/987 MB:  97.41 %)
# TRANSFERRING ||#######################################.||(962/987 MB:  97.46 %)
# TRANSFERRING ||########################################||(962/987 MB:  97.50 %)
# TRANSFERRING ||########################################||(963/987 MB:  97.54 %)
# TRANSFERRING ||########################################||(963/987 MB:  97.57 %)
# TRANSFERRING ||########################################||(963/987 MB:  97.59 %)
# TRANSFERRING ||########################################||(964/987 MB:  97.62 %)
# TRANSFERRING ||########################################||(964/987 MB:  97.64 %)
# TRANSFERRING ||########################################||(964/987 MB:  97.66 %)
# TRANSFERRING ||########################################||(964/987 MB:  97.69 %)
# TRANSFERRING ||########################################||(964/987 MB:  97.71 %)
# TRANSFERRING ||########################################||(965/987 MB:  97.73 %)
# TRANSFERRING ||########################################||(965/987 MB:  97.76 %)
# TRANSFERRING ||########################################||(965/987 MB:  97.81 %)
# TRANSFERRING ||########################################||(966/987 MB:  97.85 %)
# TRANSFERRING ||########################################||(966/987 MB:  97.88 %)
# TRANSFERRING ||########################################||(966/987 MB:  97.91 %)
# TRANSFERRING ||########################################||(967/987 MB:  97.94 %)
# TRANSFERRING ||########################################||(967/987 MB:  97.97 %)
# TRANSFERRING ||########################################||(967/987 MB:  98.00 %)
# TRANSFERRING ||########################################||(968/987 MB:  98.03 %)
# TRANSFERRING ||########################################||(968/987 MB:  98.06 %)
# TRANSFERRING ||########################################||(968/987 MB:  98.10 %)
# TRANSFERRING ||########################################||(969/987 MB:  98.14 %)
# TRANSFERRING ||########################################||(969/987 MB:  98.18 %)
# TRANSFERRING ||########################################||(969/987 MB:  98.21 %)
# TRANSFERRING ||########################################||(970/987 MB:  98.25 %)
# TRANSFERRING ||########################################||(970/987 MB:  98.29 %)
# TRANSFERRING ||########################################||(971/987 MB:  98.34 %)
# TRANSFERRING ||########################################||(971/987 MB:  98.38 %)
# TRANSFERRING ||########################################||(971/987 MB:  98.42 %)
# TRANSFERRING ||########################################||(972/987 MB:  98.46 %)
# TRANSFERRING ||########################################||(972/987 MB:  98.51 %)
# TRANSFERRING ||########################################||(973/987 MB:  98.54 %)
# TRANSFERRING ||########################################||(973/987 MB:  98.57 %)
# TRANSFERRING ||########################################||(973/987 MB:  98.59 %)
# TRANSFERRING ||########################################||(973/987 MB:  98.62 %)
# TRANSFERRING ||########################################||(974/987 MB:  98.64 %)
# TRANSFERRING ||########################################||(974/987 MB:  98.66 %)
# TRANSFERRING ||########################################||(974/987 MB:  98.69 %)
# TRANSFERRING ||########################################||(974/987 MB:  98.71 %)
# TRANSFERRING ||########################################||(974/987 MB:  98.73 %)
# TRANSFERRING ||########################################||(975/987 MB:  98.76 %)
# TRANSFERRING ||########################################||(975/987 MB:  98.79 %)
# TRANSFERRING ||########################################||(975/987 MB:  98.82 %)
# TRANSFERRING ||########################################||(976/987 MB:  98.84 %)
# TRANSFERRING ||########################################||(976/987 MB:  98.86 %)
# TRANSFERRING ||########################################||(976/987 MB:  98.87 %)
# TRANSFERRING ||########################################||(976/987 MB:  98.88 %)
# TRANSFERRING ||########################################||(976/987 MB:  98.89 %)
# TRANSFERRING ||########################################||(976/987 MB:  98.91 %)
# TRANSFERRING ||########################################||(976/987 MB:  98.93 %)
# TRANSFERRING ||########################################||(977/987 MB:  98.95 %)
# TRANSFERRING ||########################################||(977/987 MB:  98.99 %)
# TRANSFERRING ||########################################||(977/987 MB:  99.03 %)
# TRANSFERRING ||########################################||(978/987 MB:  99.07 %)
# TRANSFERRING ||########################################||(978/987 MB:  99.11 %)
# TRANSFERRING ||########################################||(979/987 MB:  99.15 %)
# TRANSFERRING ||########################################||(979/987 MB:  99.19 %)
# TRANSFERRING ||########################################||(980/987 MB:  99.24 %)
# TRANSFERRING ||########################################||(980/987 MB:  99.28 %)
# TRANSFERRING ||########################################||(980/987 MB:  99.32 %)
# TRANSFERRING ||########################################||(981/987 MB:  99.35 %)
# TRANSFERRING ||########################################||(981/987 MB:  99.38 %)
# TRANSFERRING ||########################################||(981/987 MB:  99.41 %)
# TRANSFERRING ||########################################||(982/987 MB:  99.45 %)
# TRANSFERRING ||########################################||(982/987 MB:  99.48 %)
# TRANSFERRING ||########################################||(982/987 MB:  99.49 %)
# TRANSFERRING ||########################################||(982/987 MB:  99.51 %)
# TRANSFERRING ||########################################||(982/987 MB:  99.53 %)
# TRANSFERRING ||########################################||(983/987 MB:  99.55 %)
# TRANSFERRING ||########################################||(983/987 MB:  99.58 %)
# TRANSFERRING ||########################################||(983/987 MB:  99.61 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.64 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.68 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.71 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.73 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.75 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.75 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.76 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.77 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.78 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.80 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.82 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.84 %)
# TRANSFERRING ||########################################||(986/987 MB:  99.86 %)
# TRANSFERRING ||########################################||(986/987 MB:  99.88 %)
# TRANSFERRING ||########################################||(986/987 MB:  99.89 %)
# TRANSFERRING ||########################################||(986/987 MB:  99.91 %)
# TRANSFERRING ||########################################||(986/987 MB:  99.93 %)
# TRANSFERRING ||########################################||(987/987 MB:  99.95 %)
# TRANSFERRING ||########################################||(987/987 MB:  99.97 %)
# TRANSFERRING ||########################################||(987/987 MB:  99.98 %)
# TRANSFERRING ||########################################||(987/987 MB:  99.99 %)
# TRANSFERRING ||########################################||(987/987 MB:  99.99 %)
# TRANSFERRING ||########################################||(987/987 MB: 100.00 %)
# TRANSFERRING ||########################################||(987/987 MB: 100.00 %)
# Download finished: /kaggle/working/kcg-ml/./downloads/pixel-art-pinterest-030.zip
# TRANSFERRING ||########################################||(987/987 MB: 100.00 %)

# %% [markdown]
# # Preprocess the Dataset images (Stage 1)
#
# Process a tagged dataset and computes the images metadata along with its CLIP embeddings and writes the result into a JSON file in specified output folder. In addition, the SQLite database named `dataset_cache.sqlite` with table named `dataset_cache` containing file name, hash and file path for dataset images will be created in the `./output` folder.

# %%
# %%capture
# %pip install ascii_graph open_clip_torch patool fire

# %% [markdown]
# ### Extract Downloaded ZIP-Archived Data (Optional)
# This step is optional. If this step is not performed, Stage 1 will perform the extraction

# %%
from zipfile import ZipFile


# Specify location of downloaded data (zip file)
downloaded_data_zip = '/kaggle/working/kcg-ml/downloads/pixel-art-tagged-v3.zip'
# Location to extract the zip file to
dataset_path = f'./datasets/{os.path.splitext(os.path.split(downloaded_data_zip)[-1])[0]}'
with ZipFile(downloaded_data_zip) as zip_object:
    zip_object.extractall(dataset_path)

# %% [markdown]
# ### Import the Module/Utility

# %%
import sys
sys.path.insert(0, './image-tagging-pipeline/data_loader/')
sys.path.insert(0, './image-tagging-pipeline/train/')
sys.path.insert(0, './image-tagging-pipeline/classify/')
from ImageDatasetProcessor import ImageDatasetProcessor
from classify import main as classify_main
from train import main as train_main
from classify_helper_functions import *
import patoolib
import shutil

# %% [markdown]
# ### Set Required Variables by the Utility
#
# Initialize the required parameters needed by the dataset preprocessor utility and they are described as follows:
#
# * `input_folder` _[str]_ -  path to the directory containing sub-folders of each tag.
# * `output_folder` _[str]_ - path to the directory where to save the files into it.
# * `clip_model` _[str]_ - CLIP model to be used
# * `pretrained` _[str]_ - the pre-trained model to be used for CLIP
# * `batch_size` _[int]_ -  number of images to process at a time
# * `num_threads` _[int]_ - the number to be used in this process
# * `device` _[str]_ -  the device to be used in computing the CLIP embeddings, if `None` is provided then `cuda` will be used if available

# %%
# Specify the path to the dataset in dataset_path variable
# dataset_path = '/content/downloads/pixel-art-tagged-v3.zip'
dataset_path = './datasets/testdata.zip'
output_folder = './output'
tagged_dataset = True
clip_model = 'ViT-L-14'
pretrained = 'openai'
batch_size = 32
num_threads = 4
device = None

# %% [markdown]
# ### Run the Preprocessor

# %%
ImageDatasetProcessor.process_dataset(
    dataset_path, 
    output_folder,
    tagged_dataset, 
    clip_model, 
    pretrained,
    batch_size, 
    num_threads, 
    device
)
# Out:
# 100%|███████████████████████████████████████| 933M/933M [00:16<00:00, 58.2MiB/s]
# patool: Extracting ./datasets/testdata.zip ...
# patool: running /usr/bin/7z x -o./datasets/testdata-decompressed-tmp -- ./datasets/testdata.zip
# patool: ... ./datasets/testdata.zip extracted to `./datasets/testdata-decompressed-tmp'.
# is archive dataset
# dataset folder path  = ./datasets/testdata-decompressed-tmp/testdata
# Processing...
# 100%|██████████| 1/1 [00:06<00:00,  6.93s/it]
# [INFO] Writing to database table in ./output/dataset_cache.sqlite
# [INFO] Finished.

# %% [markdown]
# # Train the Classifiers (Stage 2)
# Given a `metadata` json file containing embeddings for images and `tag-to-image-hash` json file containing images' hash with tags, the script start to make for every tag two binary classification models and save it in output folder.

# %% [markdown]
# ### Train Script Variables
#
# * `metadata_json` _[string]_ - _[required]_ - The path to the metadata json file.
# * `tag_to_hash_json` _[string]_ - _[required]_ - The path to tag-to-hash json file.
# * `output` _[string]_ - _[optional]_ - The path to the output directory.
# * `test_per` _[float]_ - _[optional]_ - The percentage of the test images from the dataset, default = 0.1

# %%
# Run from ./image-tagging-tools directory
metadata_json = './output/input-metadata.json' 
tag_to_hash_json = './output/input-tag-to-image-hash-list.json'
output_dir = './output'
test_per = 0.1

# %% [markdown]
# ## Run the training script

# %%
train_main(
    metadata_json = metadata_json,
    tag_to_hash_json = tag_to_hash_json,
    output_dir = output_dir,
    test_per = test_per
)
# Out:
# Initialize new classifier model for type: ovr-logistic-regression and tag: not-pixel-art
# Initialize new classifier model for type: ovr-svm and tag: not-pixel-art
# Initialize new classifier model for type: torch-logistic-regression and tag: not-pixel-art
# Initialize new classifier model for type: ovr-logistic-regression and tag: not-pixel-art-real-photo
# Initialize new classifier model for type: ovr-svm and tag: not-pixel-art-real-photo
# Initialize new classifier model for type: torch-logistic-regression and tag: not-pixel-art-real-photo
# [INFO] Finished.

# %% [markdown]
# ## Get list of Type and Tag Pairs from All Models

# %%
from model_api.model_api import ModelApi
# Creating model object
model_api = ModelApi()
type_tag_pair = model_api.get_type_tag_pair() 
print (type_tag_pair)
# Out:
# [('torch-logistic-regression', 'not-pixel-art'), ('ovr-svm', 'not-pixel-art-real-photo'), ('ovr-logistic-regression', 'not-pixel-art'), ('ovr-logistic-regression', 'not-pixel-art-real-photo'), ('ovr-svm', 'not-pixel-art'), ('torch-logistic-regression', 'not-pixel-art-real-photo')]

# %% [markdown]
# # Classify Data (Stage 3)
# Running the classifier. The script will loop over every image and make the classification for it using every binary classification model. Running the classifier can be performed from command line interface (CLI) or within Python runtime as shown in the following examples.

# %% [markdown]
# ## Running the classifier from Command Line Interface (CLI Version)

# %%
# !python ./image-tagging-pipeline/classify/classify.py --directory=$dataset_path --metadata_json=./output/input-metadata.json --output=./output --output_bins=10 --model_type=ovr-logistic-regression --tag=not-pixel-art
# Out:
# [INFO] Output folder ./output/tagging_output_2023_3_18_12_10_40
#   0%|                                                     | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s][INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
#
# 2it [00:00, 17.84it/s] Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
#
# 9it [00:00, 42.92it/s] Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
#
# 14it [00:00, 26.11it/s] Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
#
# 19it [00:00, 26.63it/s] Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# 24it [00:00, 30.87it/s]
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  1.29it/s]
# ./output//zip_score_cache.sqlite
# [INFO] Writing to database table in ./output//zip_score_cache.sqlite
# [INFO] Finished.

# %% [markdown]
# *italicized text*### CLI Arguments
#
# * `directory` _[string]_ - _[required]_ - The path to the images' folder or images' .zip file.
# * `metadata_json` _[string]_ - _[required]_ - The path to the metadata json file for CLIP embeddings.
# * `output` _[string]_ - _[optional]_ - The path to the output directory for the inference results.
# * `model_type` _[string]_ - _[required]_ - The type of the model (example: `ovr-logistic-regression`, `ovr-svm`, `torch-logistic-regression`).
# * `tag` _[string]_ - _[required]_ - Tag string (example: `pos-character`, `pos-environmental-space`, etc).
# * `output_bins` _[int]_ - _[optional]_ -  The number of bins of the results for each model.
#
# If the `--output` argument is not specified, the classification / inference result will be placed at `./output/tagging_output` folder. Time stamp will be appended to folder name (for example: `./output/tagging_output_2023_1_21_0_56`).
# In addition, the SQLite database named `score_cache.sqlite` with table named `score_cache` containing file name, file path, file hash, model name, model type, model train date, tag string and tag score for given images will be created in the `./output` folder. For archived (ZIP) files the SQLite database named `zip_score_cache.sqlite` with table named `zip_score_cache` containing file name, file path, archive path, type of file, hash, model type, tag name and tag score for given images will be created in the `output` folder.

# %% [markdown]
# ## Running the Classifier (from Python Runtime)
#
# ### Variables for Classifier
# * `data_path` _[string]_ - _[required]_ - The path to the images data folder or single image file'.
# * `json_file_path` _[string]_ - _[required]_ - The path to the metadata json file for CLIP embeddings.
# * `output_dir` _[string]_ - _[optional]_ - The path to the output directory for the inference results.
# * `model_type` _[string]_ - _[required]_ - The type of the model (example: `ovr-logistic-regression`, `ovr-svm`, `torch-logistic-regression`)
# * `tag` _[string]_ - _[required]_ - Tag string (example: `pos-character`, `pos-environmental-space`, etc).
# * `bins_number` _[int]_ - _[optional]_ -  The number of bins of the results for each model.

# %% [markdown]
# ### Classify Images Data in Folder with Single Model

# %%
# Specify path to folder containing images data in data_path variable
# data_path = '../path/to/image/data/folder/'
# Or test with images in dataset
data_path    = dataset_path
output_dir     = './output/classification_single_image_single_model'
json_file_path = './output/input-metadata.json'
bins_number    = 10
# Specify the type of model
model_type = 'ovr-logistic-regression'
# Specify the tag string
tag = 'not-pixel-art'

# %%
classify_main(
        folder_path    = data_path, 
        output_dir     = output_dir, 
        json_file_path = json_file_path, 
        bins_number = bins_number,
        model_type = model_type, 
        tag = tag
        )
# Out:
# [INFO] Output folder ./output/classification_single_image_single_model/tagging_output_2023_3_18_12_13_5
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 2it [00:00, 19.54it/s]
# [INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
# 9it [00:00, 42.63it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
# 14it [00:00, 26.52it/s]
# 18it [00:00, 29.67it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
# 24it [00:00, 30.51it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# ./output/classification_single_image_single_model//zip_score_cache.sqlite
# [INFO] Writing to database table in ./output/classification_single_image_single_model//zip_score_cache.sqlite
# [INFO] Finished.

# %% [markdown]
# ### Classify Single Image with Single Model

# %%
# Specify path to single image to be classified in data_path
#data_path    = '../path/to/image/file'
# Or test with sample image from dataset
data_path    = './datasets/testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg'
output_dir     = './output/classification_single_image_single_model'
json_file_path = './output/input-metadata.json'
bins_number    = 10
# Specify the type of model
model_type = 'torch-logistic-regression'
# Specify the tag string
tag = 'not-pixel-art'

# %%
classify_main(
        folder_path    = data_path, 
        output_dir     = output_dir, 
        json_file_path = json_file_path, 
        bins_number = bins_number,
        model_type = model_type, 
        tag = tag 
        )
# Out:
# [INFO] Output folder ./output/classification_single_image_single_model/tagging_output_2023_3_18_12_14_24
# 100%|██████████| 1/1 [00:00<00:00, 50.02it/s]
# [INFO] Writing to database table in ./output/classification_single_image_single_model//score_cache.sqlite
# [INFO] Finished.

# %% [markdown]
# ### Classify Images Data in Folder with All Models

# %%
# Specify path to folder containing images data in data_path variable
# data_path = '../path/to/image/data/folder/'
# Or test with images in dataset
data_path    = dataset_path
output_dir     = './output/'
json_file_path = './output/input-metadata.json'
bins_number    = 10

# %%
from model_api.model_api import ModelApi
# Creating model object
model_api = ModelApi()

# Get list of model type and tag pair
type_tag_pair = model_api.get_type_tag_pair() 

for model_type, tag in type_tag_pair:
        classify_main(
                folder_path    = data_path, 
                output_dir     = output_dir, 
                json_file_path = json_file_path, 
                bins_number = bins_number,
                model_type = model_type, 
                tag = tag 
                )
# Out:
# [INFO] Output folder ./output//tagging_output_2023_3_18_12_15_49
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 3it [00:00, 26.67it/s]
# [INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
# 9it [00:00, 43.41it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
# 14it [00:00, 26.07it/s]
# 18it [00:00, 28.32it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
# 24it [00:00, 28.97it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.20it/s]
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# ./output///zip_score_cache.sqlite
# [INFO] Writing to database table in ./output///zip_score_cache.sqlite
# [INFO] Finished.
# [INFO] Output folder ./output//tagging_output_2023_3_18_12_15_59
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 3it [00:00, 26.46it/s]
# [INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
# 9it [00:00, 39.71it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
# 13it [00:00, 23.36it/s]
# 18it [00:00, 29.68it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
# 24it [00:00, 30.11it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.25it/s]
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# ./output///zip_score_cache.sqlite
# [INFO] Writing to database table in ./output///zip_score_cache.sqlite
# [INFO] Finished.
# [INFO] Output folder ./output//tagging_output_2023_3_18_12_16_9
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 2it [00:00, 18.68it/s]
# [INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
# 8it [00:00, 41.22it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
# 13it [00:00, 24.08it/s]
# 17it [00:00, 27.70it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
# 24it [00:00, 29.62it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# ./output///zip_score_cache.sqlite
# [INFO] Writing to database table in ./output///zip_score_cache.sqlite
# [INFO] Finished.
# [INFO] Output folder ./output//tagging_output_2023_3_18_12_16_19
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 2it [00:00, 19.61it/s]
# [INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
# 8it [00:00, 42.72it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
# 13it [00:00, 23.99it/s]
# 17it [00:00, 28.02it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
# 24it [00:00, 30.03it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# ./output///zip_score_cache.sqlite
# [INFO] Writing to database table in ./output///zip_score_cache.sqlite
# [INFO] Finished.
# [INFO] Output folder ./output//tagging_output_2023_3_18_12_16_29
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 1it [00:00,  7.97it/s]
# [INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
# 6it [00:00, 29.07it/s]
# 10it [00:00, 28.67it/s]
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
# 13it [00:00, 17.17it/s]
# 17it [00:00, 22.19it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
# 24it [00:00, 24.54it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.01it/s]
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# ./output///zip_score_cache.sqlite
# [INFO] Writing to database table in ./output///zip_score_cache.sqlite
# [INFO] Finished.
# [INFO] Output folder ./output//tagging_output_2023_3_18_12_16_39
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 3it [00:00, 26.79it/s]
# [INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
# 9it [00:00, 43.05it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
# 14it [00:00, 26.14it/s]
# 18it [00:00, 29.62it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
# 24it [00:00, 30.53it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# ./output///zip_score_cache.sqlite
# [INFO] Writing to database table in ./output///zip_score_cache.sqlite
# [INFO] Finished.

# %% [markdown]
# ### Classification for 'other-validation' Folder (pre-computed CLIP embeddings)

# %%
# Specify path to dataset folder containing 'other-validation' folder in dataset_path variable
dataset_path = 'datasets/testdata'
other_validation_path = os.path.join(dataset_path,'other-validation')
output_dir     = './output/classification_other_validation'
json_file_path =  './output/input-metadata.json'
bins_number    = 10
# Specify the type of model
model_type = 'ovr-logistic-regression'
# Specify the tag string
tag = 'not-pixel-art'

# %%
classify_main(
        folder_path    = other_validation_path, 
        output_dir     = output_dir, 
        json_file_path = json_file_path, 
        bins_number    = bins_number, 
        model_type = model_type, 
        tag = tag 
        )
# Out:
# [INFO] Output folder ./output/classification_other_validation/tagging_output_2023_3_18_12_18_33
# 100%|██████████| 4/4 [00:00<00:00, 137.90it/s]
# [INFO] Writing to database table in ./output/classification_other_validation//score_cache.sqlite
# [INFO] Finished.

# %% [markdown]
# ### Get Score for Images Data in ZIP Archive with Single Model (Tag) and Run Function Based on Score

# %%
from classify_helper_functions import zip_gen, get_single_tag_score, get_clip, get_classifier_model

# Specify ZIP archive containing images data
folder_path    = './datasets/testdata.zip'
# Specify the type of model
model_type = 'ovr-logistic-regression'
# Specify the tag string
tag = 'not-pixel-art'
# Score threshold to run the function
th_score       = 0.2

# %%
def any_function_to_run(score):
    '''Function to run when certain prob_score is met'''
    print ('OK')

# %%
clip_model , preprocess , device = get_clip(clip_model_type= 'ViT-L-14',pretrained= 'openai')
model = get_classifier_model(model_type = model_type, tag = tag)
print (model)

# If model not found then return
if model != {}:
    # Loop through each zip file.
    for file in [folder_path]:
        # Generating images
        for img, img_file_name in zip_gen(file):
            # Calculate score
            score = get_single_tag_score(img, img_file_name, model, clip_model, preprocess, 'cpu') #Change Device with CPU becuase input type will be same as Weight.
            print (f'[INFO] Score: {score}')
            if th_score < score:
                any_function_to_run(score)
else:
    print ('[INFO]: Model not found. No classification performed.')

print("[INFO] Finished.")
# Out:
# {'classifier': LogisticRegressionPytorch(
#   (linear): Linear(in_features=768, out_features=1, bias=True)
# ), 'model_type': 'torch-logistic-regression', 'train_start_time': datetime.datetime(2023, 3, 18, 12, 6, 3, 654802), 'tag': 'not-pixel-art'}
# [INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
# [INFO] Score: 0.9889920949935913
# OK
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
# [INFO] Score: 0.9995513791509438
# OK
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
# [INFO] Score: 0.999265631835442
# OK
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
# [INFO] Score: 0.9993328645359725
# OK
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
# [INFO] Score: 0.9965098439715803
# OK
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
# [INFO] Score: 0.9976044727955014
# OK
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
# [INFO] Score: 0.9991793296067044
# OK
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
# [INFO] Score: 0.9963077697902918
# OK
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
# [INFO] Score: 0.9999580026778858
# OK
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
# [INFO] Score: 0.9998809294193052
# OK
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
# [INFO] Score: 0.9998074582690606
# OK
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
# [INFO] Score: 0.9997849011269864
# OK
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
# [INFO] Score: 0.9999048188183224
# OK
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
# [INFO] Score: 0.9964821657631546
# OK
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
# [INFO] Score: 0.9998205723095452
# OK
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
# [INFO] Score: 0.9998305304325186
# OK
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
# [INFO] Score: 0.6447329521179199
# OK
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
# [INFO] Score: 0.00022679567337036133
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
# [INFO] Score: 0.00015616416931152344
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
# [INFO] Score: 0.0004062056541442871
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
# [INFO] Score: 0.7402222454547882
# OK
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
# [INFO] Score: 0.1888580322265625
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
# [INFO] Score: 0.9924280317500234
# OK
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# [INFO] Score: 0.013740181922912598
# [INFO] Finished.

# %% [markdown]
# ## ZIP Archive: Reading Image Files, Compute CLIP and Send to Single Classifier (based on Type and Tag)

# %% [markdown]
# ### Import Required Functions

# %%
import sys
sys.path.insert(0, './image-tagging-pipeline/classify/')
import os
import datetime
import numpy as np
from classify import zip_gen as zip_image_iterator
from classify_helper_functions import file_to_hash_zip, load_json, get_clip, get_classifier_model, clip_image_features_zip, classify_image_prob, get_bins_array, find_bin, make_dir

# %% [markdown]
# ### Specify ZIP Archive Location, Model Type and Tag

# %%
# Specify ZIP archive containing images data
zip_file_path = './datasets/testdata.zip'
# Specify folder path to write classified images
output_dir = './output'
# Metadata json file location
json_file_path = './output/input-metadata.json'
# Specify the type of model
model_type = 'ovr-logistic-regression'
# Specify the tag string
tag = 'not-pixel-art'
# Number of classification score (probability) bins
n_bins = 10

# %% [markdown]
# ### Create Classifier and CLIP Model

# %%
# Get classifier model
model = get_classifier_model(model_type = model_type, tag = tag)
if model != {}:
    classifier = model['classifier']
    torch_model = 'torch' in model['model_type']
    # Get CLIP model, to calculate CLIP embeddings if it's not in .json metadata file.
    clip_model , preprocess , device = get_clip(clip_model_type= 'ViT-L-14',pretrained= 'openai')
    # Creating bins
    bins  = get_bins_array(n_bins)
else:
    print ('[INFO]: Model not found. Unable to perform classification')

# %% [markdown]
# ### Reading, Compute CLIP and Send to Single Classifier for Each File in ZIP Archive

# %%
# Loop through each zip file.
for file in [zip_file_path]:
    # Reading image files from ZIP archive
    for img, img_file_name in zip_image_iterator(file):

        # Hash
        hash_id = file_to_hash_zip(img, img_file_name)

        # Load the .json file.
        metadata_json_obj = load_json(json_file_path)

        # Clip features
        try : 
            # Check whether the hash_id exists in json file.
            image_features = np.array(metadata_json_obj[hash_id]["embeddings_vector"]).reshape(1,-1) 
        except:
            # hash_id does not exist in json file. Calculate image features.
            image_features = clip_image_features_zip(img, img_file_name, clip_model,preprocess,device) 

        # Calculate probability score
        score = classify_image_prob(image_features, classifier, torch_model=torch_model)
        print (score)

        # Get the bins 
        tag_bin, _= find_bin(bins , score) # get the bins 
        print (tag_bin)

        # Create folder for writing classified
        timestamp = datetime.datetime.now() 
        output_sub_dir = (f'tagging_output-{timestamp.year}_{timestamp.month}_{timestamp.day}_{timestamp.hour}_{timestamp.minute}_{timestamp.second}')
        tag_name_out_folder = make_dir([output_dir, output_sub_dir, f'{model_type}',f'{tag}',tag_bin])
    
        # Saving the image to file
        file_path = os.path.join(tag_name_out_folder, os.path.basename(img_file_name))
        img.save(file_path)
        print (f'[INFO] File {file_path} saved')

print("[INFO] Finished.")
# Out:
# [INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
# 0.9482170251556937
# 0.9
# [INFO] File ./output/tagging_output-2023_3_18_12_54_55/ovr-logistic-regression/not-pixel-art/0.9/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg saved
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
# 0.9840780402187936
# 1.0
# [INFO] File ./output/tagging_output-2023_3_18_12_54_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg saved
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
# 0.978165190786032
# 1.0
# [INFO] File ./output/tagging_output-2023_3_18_12_54_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg saved
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
# 0.9744314985180317
# 1.0
# [INFO] File ./output/tagging_output-2023_3_18_12_54_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg saved
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
# 0.9658955260899013
# 1.0
# [INFO] File ./output/tagging_output-2023_3_18_12_54_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg saved
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
# 0.9668851012569167
# 1.0
# [INFO] File ./output/tagging_output-2023_3_18_12_54_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg saved
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
# 0.9877531229325527
# 1.0
# [INFO] File ./output/tagging_output-2023_3_18_12_54_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg saved
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
# 0.9571123065489703
# 1.0
# [INFO] File ./output/tagging_output-2023_3_18_12_54_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg saved
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
# 0.9945829003741107
# 1.0
# [INFO] File ./output/tagging_output-2023_3_18_12_54_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg saved
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
# 0.9925369331042665
# 1.0
# [INFO] File ./output/tagging_output-2023_3_18_12_54_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg saved
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
# 0.9877950541327127
# 1.0
# [INFO] File ./output/tagging_output-2023_3_18_12_54_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg saved
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
# 0.9878805320819664
# 1.0
# [INFO] File ./output/tagging_output-2023_3_18_12_54_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png saved
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
# 0.9918228153532478
# 1.0
# [INFO] File ./output/tagging_output-2023_3_18_12_54_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg saved
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
# 0.9637026424967896
# 1.0
# [INFO] File ./output/tagging_output-2023_3_18_12_54_56/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png saved
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
# 0.9856858117953607
# 1.0
# [INFO] File ./output/tagging_output-2023_3_18_12_54_56/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg saved
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
# 0.9906169535776125
# 1.0
# [INFO] File ./output/tagging_output-2023_3_18_12_54_56/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg saved
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
# 0.7848414935566623
# 0.8
# [INFO] File ./output/tagging_output-2023_3_18_12_54_56/ovr-logistic-regression/not-pixel-art/0.8/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg saved
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
# 0.01997718997544451
# 0.1
# [INFO] File ./output/tagging_output-2023_3_18_12_54_56/ovr-logistic-regression/not-pixel-art/0.1/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png saved
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
# 0.0179756857830895
# 0.1
# [INFO] File ./output/tagging_output-2023_3_18_12_54_56/ovr-logistic-regression/not-pixel-art/0.1/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png saved
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
# 0.031124860965745182
# 0.1
# [INFO] File ./output/tagging_output-2023_3_18_12_54_56/ovr-logistic-regression/not-pixel-art/0.1/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg saved
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
# 0.7591911342080029
# 0.8
# [INFO] File ./output/tagging_output-2023_3_18_12_54_56/ovr-logistic-regression/not-pixel-art/0.8/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg saved
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
# 0.6557208316074574
# 0.7
# [INFO] File ./output/tagging_output-2023_3_18_12_54_56/ovr-logistic-regression/not-pixel-art/0.7/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png saved
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
# 0.9389613642070731
# 0.9
# [INFO] File ./output/tagging_output-2023_3_18_12_54_56/ovr-logistic-regression/not-pixel-art/0.9/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg saved
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# 0.18280870383153225
# 0.2
# [INFO] File ./output/tagging_output-2023_3_18_12_54_56/ovr-logistic-regression/not-pixel-art/0.2/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png saved
# [INFO] Finished.

# %% [markdown]
# # Using Classifier Model API
# ### Create Classifier Model API Object

# %%
from model_api.model_api import ModelApi

# Create model loader object with default model_path='./output/models/'
model_api = ModelApi()
# Or specify model_path explicitly'
# model_api = ModelApi(model_path='./output/models')

# %% [markdown]
# ### Get List of Model Types

# %%
model_types = model_api.get_model_types()
print (model_types)
# Out:
# ['torch-logistic-regression', 'ovr-svm', 'ovr-logistic-regression', 'ovr-logistic-regression', 'ovr-svm', 'torch-logistic-regression']

# %% [markdown]
# ### Get List of Tags Based on Model Type

# %%
model_type = (model_types[0])
tags = model_api.get_tags_by_model_type(model_type)
print (tags)
# Out:
# ['not-pixel-art', 'not-pixel-art-real-photo']

# %% [markdown]
# ### Get List of Type and Tag Pairs from All Models'''

# %%
type_tag_pair = model_api.get_type_tag_pair()
print (type_tag_pair)


#type_tag_pair is a list of tupple with the following structure
#[(<model_type>,<tag>)]
# Out:
# [('torch-logistic-regression', 'not-pixel-art'), ('ovr-svm', 'not-pixel-art-real-photo'), ('ovr-logistic-regression', 'not-pixel-art'), ('ovr-logistic-regression', 'not-pixel-art-real-photo'), ('ovr-svm', 'not-pixel-art'), ('torch-logistic-regression', 'not-pixel-art-real-photo')]

# %% [markdown]
# ### Get Model Based On Model Type and Tag

# %%
# Specify model type and tag
model_type, tag = type_tag_pair[0]
# Get the model dictionary
model = model_api.get_model_by_type_tag(model_type, tag)
print(model)

#Model is a dictionary with the following structure
#{'classifier' : <model object>,
#'model_type' : <model type string>,
#'train_start_time' : <training start time datetime object>
#'tag' : <tag string>
#}
# Out:
# {'classifier': LogisticRegressionPytorch(
#   (linear): Linear(in_features=768, out_features=1, bias=True)
# ), 'model_type': 'torch-logistic-regression', 'train_start_time': datetime.datetime(2023, 3, 18, 12, 6, 3, 654802), 'tag': 'not-pixel-art'}

# %% [markdown]
# ### Get Models Dictionary for All Model Pickle Files

# %%
models_dict = model_api.get_models_dict()
print(models_dict)

#Example stucture of models_dict
#{<model_name>: 
#    {'classifier' : <model object>,
#    'model_type' : <model type string>,
#    'train_start_time' : <training start time datetime object>
#    'tag' : <tag string>
#    }
#}
# Out:
# {'model-torch-logistic-regression-tag-not-pixel-art': {'classifier': LogisticRegressionPytorch(
#   (linear): Linear(in_features=768, out_features=1, bias=True)
# ), 'model_type': 'torch-logistic-regression', 'train_start_time': datetime.datetime(2023, 3, 18, 12, 6, 3, 654802), 'tag': 'not-pixel-art'}, 'model-ovr-svm-tag-not-pixel-art-real-photo': {'classifier': SVC(decision_function_shape='ovo', probability=True), 'model_type': 'ovr-svm', 'train_start_time': datetime.datetime(2023, 3, 18, 12, 6, 3, 654802), 'tag': 'not-pixel-art-real-photo'}, 'model-ovr-logistic-regression-tag-not-pixel-art': {'classifier': LogisticRegression(multi_class='ovr', random_state=0), 'model_type': 'ovr-logistic-regression', 'train_start_time': datetime.datetime(2023, 3, 18, 12, 6, 3, 654802), 'tag': 'not-pixel-art'}, 'model-ovr-logistic-regression-tag-not-pixel-art-real-photo': {'classifier': LogisticRegression(multi_class='ovr', random_state=0), 'model_type': 'ovr-logistic-regression', 'train_start_time': datetime.datetime(2023, 3, 18, 12, 6, 3, 654802), 'tag': 'not-pixel-art-real-photo'}, 'model-ovr-svm-tag-not-pixel-art': {'classifier': SVC(decision_function_shape='ovo', probability=True), 'model_type': 'ovr-svm', 'train_start_time': datetime.datetime(2023, 3, 18, 12, 6, 3, 654802), 'tag': 'not-pixel-art'}, 'model-torch-logistic-regression-tag-not-pixel-art-real-photo': {'classifier': LogisticRegressionPytorch(
#   (linear): Linear(in_features=768, out_features=1, bias=True)
# ), 'model_type': 'torch-logistic-regression', 'train_start_time': datetime.datetime(2023, 3, 18, 12, 6, 3, 654802), 'tag': 'not-pixel-art-real-photo'}}

# %% [markdown]
# # Other Examples
# #### Get Files List from Folder or ZIP Archive

# %%
from zipfile import ZipFile

# Specify the path to the images data in the folder_path variable
folder_path    = './datasets/testdata.zip'

def fetch_file_paths(data_file):
    '''Yielding contained file paths in data_file'''

    if data_file.endswith('.zip'):

        # Selected data_dir is a zip archive
        with ZipFile(data_file) as archive:
            '''Getting archive details'''
            # Listing content
            entries = archive.infolist()

            for entry in entries:
                # Do for every content in the zip file
                if not entry.is_dir():
                    
                    with archive.open(entry) as file:

                        if entry.filename.lower().endswith(('.zip')):
                            # Another zip file found in the content.
                            with ZipFile(file) as sub_archive:
                                '''Getting archive details'''
                                sub_entries = sub_archive.infolist()
                                for sub_entry in sub_entries:
                                    with sub_archive.open(sub_entry) as sub_file:
                                        img_file_name = f'{data_file}/{sub_entry.filename}'
                                        yield (img_file_name)

                        else:
                            # Should be image file.
                            img_file_name = entry.filename
                            yield (img_file_name)
    else:
        # Should be image file
        yield data_file

def get_file_paths(data_dir):

    # Placeholder for file in data_dir
    dir_list = []

    if not os.path.isfile(data_dir):
        # A normal directory
        for root, dirs, files in os.walk(data_dir):
            for file in files:
                dir_list.append(os.path.join(root, file))
    else:
        # A single file (could be a zip archive or image)
        dir_list = [data_dir]

    # Placeholder for file_path for files found
    file_path_list = []

    for file in dir_list:
        for file_path in fetch_file_paths(file):
            print (f'File: {file_path}')
            file_path_list.append(file_path)
    
    return file_path_list

get_file_paths(folder_path)
# Out:
# File: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
# File: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
# File: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
# File: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
# File: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
# File: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
# File: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
# File: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
# File: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
# File: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
# File: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
# File: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
# File: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
# File: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
# File: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
# File: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
# File: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
# File: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
# File: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
# File: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
# File: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
# File: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
# File: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
# File: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# ['testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg',
#  'testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg',
#  'testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg',
#  'testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg',
#  'testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg',
#  'testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg',
#  'testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg',
#  'testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg',
#  'testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg',
#  'testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg',
#  'testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg',
#  'testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png',
#  'testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg',
#  'testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png',
#  'testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg',
#  'testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg',
#  'testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg',
#  'testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png',
#  'testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png',
#  'testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg',
#  'testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg',
#  'testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png',
#  'testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg',
#  'testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png']

# %% [markdown]
# #### Get List of File Hash_ID from Tag Cache Based on List of Models or Specific Model

# %%
import json
from clip_cache.cache_tag import TagCache
from model_api.model_api import ModelApi

# Specify path to tag cache file
tag_cache_path = './output/tag_cache.sqlite'

# Output placeholder
model_tag_cache_pair = {}

try:
    # Create tag cache object
    tag_cache = TagCache()
    # Create model api object
    model_api=ModelApi()

    # Getting models
    models_dict = model_api.get_models_dict()
    '''
    Example stucture of models_dict
    {<model_name>: 
        {'classifier' : <model object>,
        'model_type' : <model type string>,
        'train_start_time' : <traing start time datetime object>
        'tag' : <tag string>
        }
    }
    '''

    # Get tags from models_dict
    for model in models_dict:
        # Get list of images (hash_IDs) based on each model's tag name
        hash_ids = tag_cache.get_hash_by_tag(db_path = tag_cache_path, tag = models_dict[model]['tag'])
        # Append list of hash IDs to the result dict
        model_tag_cache_pair[model] = hash_ids
    
    # Output
    print(json.dumps(model_tag_cache_pair, indent=2))

except Exception as e:
    print (f'[ERROR] {e}: Getting data from tag cache failed')
# Out:
# [ERROR] no such table: tag_cache: Getting tag failed, tag cache database does not exist or might be in use!
# [ERROR] no such table: tag_cache: Getting tag failed, tag cache database does not exist or might be in use!
# [ERROR] no such table: tag_cache: Getting tag failed, tag cache database does not exist or might be in use!
# [ERROR] no such table: tag_cache: Getting tag failed, tag cache database does not exist or might be in use!
# [ERROR] no such table: tag_cache: Getting tag failed, tag cache database does not exist or might be in use!
# [ERROR] no such table: tag_cache: Getting tag failed, tag cache database does not exist or might be in use!
# {
#   "model-torch-logistic-regression-tag-not-pixel-art": null,
#   "model-ovr-svm-tag-not-pixel-art-real-photo": null,
#   "model-ovr-logistic-regression-tag-not-pixel-art": null,
#   "model-ovr-logistic-regression-tag-not-pixel-art-real-photo": null,
#   "model-ovr-svm-tag-not-pixel-art": null,
#   "model-torch-logistic-regression-tag-not-pixel-art-real-photo": null
# }
