# %% [markdown]
# # Fetch & Clone Repo
#
# Clone the `image-tagging-tools` repo as it has all the required utils and codes from preprocessing the image datasets to training the models and using them to classify the images.

# %%
# !git clone https://github.com/kk-digital/kcg-ml
# %cd kcg-ml
# Out:
# Cloning into 'kcg-ml'...
# remote: Enumerating objects: 2927, done.
# remote: Counting objects: 100% (919/919), done.
# remote: Compressing objects: 100% (405/405), done.
# remote: Total 2927 (delta 574), reused 795 (delta 509), pack-reused 2008
# Receiving objects: 100% (2927/2927), 26.55 MiB | 14.21 MiB/s, done.
# Resolving deltas: 100% (1721/1721), done.
# /content/kcg-ml

# %%
# install the required dependencies
# !pip3 install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ascii-graph==1.5.1
#   Using cached ascii_graph-1.5.1.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Collecting asttokens==2.1.0
#   Using cached asttokens-2.1.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: backcall==0.2.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 3)) (0.2.0)
# Collecting charset-normalizer==2.1.1
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting colorama==0.4.6
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting contourpy==1.0.6
#   Using cached contourpy-1.0.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (296 kB)
# Requirement already satisfied: cycler==0.11.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 7)) (0.11.0)
# Collecting debugpy==1.6.3
#   Using cached debugpy-1.6.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.8 MB)
# Collecting decorator==5.1.1
#   Using cached decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: entrypoints==0.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 10)) (0.4)
# Collecting executing==1.2.0
#   Using cached executing-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting filelock==3.8.0
#   Using cached filelock-3.8.0-py3-none-any.whl (10 kB)
# Collecting fire==0.4.0
#   Using cached fire-0.4.0.tar.gz (87 kB)
#   Preparing metadata (setup.py) ... done
# Collecting fonttools==4.38.0
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# Collecting ftfy==6.1.1
#   Using cached ftfy-6.1.1-py3-none-any.whl (53 kB)
# Collecting huggingface-hub==0.10.1
#   Using cached huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
# Requirement already satisfied: idna==3.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 17)) (3.4)
# Collecting ipykernel==6.17.1
#   Using cached ipykernel-6.17.1-py3-none-any.whl (138 kB)
# Collecting ipython==8.6.0
#   Using cached ipython-8.6.0-py3-none-any.whl (761 kB)
# Collecting jedi==0.18.2
#   Using cached jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: joblib==1.2.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 21)) (1.2.0)
# Collecting jupyter_client==7.4.7
#   Using cached jupyter_client-7.4.7-py3-none-any.whl (133 kB)
# Collecting jupyter_core==5.0.0
#   Using cached jupyter_core-5.0.0-py3-none-any.whl (91 kB)
# Requirement already satisfied: kiwisolver==1.4.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 24)) (1.4.4)
# Collecting matplotlib==3.5.3
#   Using cached matplotlib-3.5.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 26)) (0.1.6)
# Requirement already satisfied: nest-asyncio==1.5.6 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 27)) (1.5.6)
# Requirement already satisfied: numpy==1.22.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 28)) (1.22.4)
# Collecting open-clip-torch==2.4.1
#   Using cached open_clip_torch-2.4.1-py3-none-any.whl (1.4 MB)
# Collecting packaging==21.3
#   Using cached packaging-21.3-py3-none-any.whl (40 kB)
# Requirement already satisfied: parso==0.8.3 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 31)) (0.8.3)
# Collecting patool==1.12
#   Using cached patool-1.12-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: pickleshare==0.7.5 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 33)) (0.7.5)
# Collecting Pillow==9.3.0
#   Using cached Pillow-9.3.0-cp39-cp39-manylinux_2_28_x86_64.whl (3.3 MB)
# Collecting platformdirs==2.5.4
#   Using cached platformdirs-2.5.4-py3-none-any.whl (14 kB)
# Collecting prompt-toolkit==3.0.33
#   Using cached prompt_toolkit-3.0.33-py3-none-any.whl (383 kB)
# Requirement already satisfied: psutil==5.9.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 37)) (5.9.4)
# Collecting pure-eval==0.2.2
#   Using cached pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting Pygments==2.13.0
#   Using cached Pygments-2.13.0-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: pyparsing==3.0.9 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 40)) (3.0.9)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 41)) (2.8.2)
# Collecting python-fire==0.1.0
#   Using cached python_fire-0.1.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: PyYAML==6.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 43)) (6.0)
# Collecting pyzmq==24.0.1
#   Using cached pyzmq-24.0.1-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
# Requirement already satisfied: regex==2022.10.31 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 45)) (2022.10.31)
# Collecting requests==2.28.1
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Collecting scikit-learn==1.0.2
#   Using cached scikit_learn-1.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.4 MB)
# Collecting scipy==1.7.3
#   Using cached scipy-1.7.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.8 MB)
# Requirement already satisfied: six==1.16.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 49)) (1.16.0)
# Collecting stack-data==0.6.1
#   Downloading stack_data-0.6.1-py3-none-any.whl (24 kB)
# Collecting termcolor==2.1.1
#   Downloading termcolor-2.1.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: threadpoolctl==3.1.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 52)) (3.1.0)
# Collecting torch==1.13.0
#   Downloading torch-1.13.0-cp39-cp39-manylinux1_x86_64.whl (890.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.2/890.2 MB 1.9 MB/s eta 0:00:00
# Collecting torchvision==0.14.0
#   Downloading torchvision-0.14.0-cp39-cp39-manylinux1_x86_64.whl (24.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.3/24.3 MB 58.8 MB/s eta 0:00:00
# Requirement already satisfied: tornado==6.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 55)) (6.2)
# Collecting tqdm==4.64.1
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 10.9 MB/s eta 0:00:00
# Collecting traitlets==5.5.0
#   Downloading traitlets-5.5.0-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 14.1 MB/s eta 0:00:00
# Collecting typing_extensions==4.4.0
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Collecting urllib3==1.26.12
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.4/140.4 kB 20.0 MB/s eta 0:00:00
# Collecting wcwidth==0.2.5
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting wincertstore==0.2
#   Downloading wincertstore-0.2-py2.py3-none-any.whl (8.8 kB)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from ipython==8.6.0->-r requirements.txt (line 19)) (4.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests==2.28.1->-r requirements.txt (line 46)) (2022.12.7)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 71.5 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.9 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 80.0 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->-r requirements.txt (line 53)) (67.6.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->-r requirements.txt (line 53)) (0.40.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect>4.3->ipython==8.6.0->-r requirements.txt (line 19)) (0.7.0)
# Building wheels for collected packages: ascii-graph, fire
#   Building wheel for ascii-graph (setup.py) ... done
#   Created wheel for ascii-graph: filename=ascii_graph-1.5.1-py3-none-any.whl size=11835 sha256=34f825116a4a801f5c328d97041e4cf309a804e20609df5e5328f6e72be29d6c
#   Stored in directory: /root/.cache/pip/wheels/4f/b2/73/6aead9f603acd61634cd155868ee09acf62345972af6c5fb40
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115941 sha256=e11f601641a9bc998e5a87ec2c60a88264be351818b71fc13ca337ace1400c66
#   Stored in directory: /root/.cache/pip/wheels/2a/93/86/8cd17bc6c40fb605c3ac549d0b860ef7e84ee5f67bf01a3287
# Successfully built ascii-graph fire
# Installing collected packages: wincertstore, wcwidth, pure-eval, patool, executing, ascii-graph, urllib3, typing_extensions, traitlets, tqdm, termcolor, scipy, pyzmq, Pygments, prompt-toolkit, platformdirs, Pillow, packaging, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, jedi, ftfy, fonttools, filelock, decorator, debugpy, contourpy, colorama, charset-normalizer, asttokens, stack-data, scikit-learn, requests, python-fire, nvidia-cudnn-cu11, matplotlib, jupyter_core, fire, torch, jupyter_client, ipython, huggingface-hub, torchvision, ipykernel, open-clip-torch
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.6
#     Uninstalling wcwidth-0.2.6:
#       Successfully uninstalled wcwidth-0.2.6
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.15
#     Uninstalling urllib3-1.26.15:
#       Successfully uninstalled urllib3-1.26.15
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.2.0
#     Uninstalling termcolor-2.2.0:
#       Successfully uninstalled termcolor-2.2.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 23.2.1
#     Uninstalling pyzmq-23.2.1:
#       Successfully uninstalled pyzmq-23.2.1
#   Attempting uninstall: Pygments
#     Found existing installation: Pygments 2.14.0
#     Uninstalling Pygments-2.14.0:
#       Successfully uninstalled Pygments-2.14.0
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.38
#     Uninstalling prompt-toolkit-3.0.38:
#       Successfully uninstalled prompt-toolkit-3.0.38
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 3.2.0
#     Uninstalling platformdirs-3.2.0:
#       Successfully uninstalled platformdirs-3.2.0
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.0
#     Uninstalling packaging-23.0:
#       Successfully uninstalled packaging-23.0
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.39.3
#     Uninstalling fonttools-4.39.3:
#       Successfully uninstalled fonttools-4.39.3
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.11.0
#     Uninstalling filelock-3.11.0:
#       Successfully uninstalled filelock-3.11.0
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: debugpy
#     Found existing installation: debugpy 1.6.6
#     Uninstalling debugpy-1.6.6:
#       Successfully uninstalled debugpy-1.6.6
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.0.7
#     Uninstalling contourpy-1.0.7:
#       Successfully uninstalled contourpy-1.0.7
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.0.12
#     Uninstalling charset-normalizer-2.0.12:
#       Successfully uninstalled charset-normalizer-2.0.12
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: jupyter_core
#     Found existing installation: jupyter_core 5.3.0
#     Uninstalling jupyter_core-5.3.0:
#       Successfully uninstalled jupyter_core-5.3.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
#   Attempting uninstall: jupyter_client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.1+cu118
#     Uninstalling torchvision-0.15.1+cu118:
#       Successfully uninstalled torchvision-0.15.1+cu118
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.5.6
#     Uninstalling ipykernel-5.5.6:
#       Successfully uninstalled ipykernel-5.5.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.15.1 requires torch==2.0.0, but you have torch 1.13.0 which is incompatible.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 1.13.0 which is incompatible.
# torchaudio 2.0.1+cu118 requires torch==2.0.0, but you have torch 1.13.0 which is incompatible.
# nbclient 0.7.3 requires jupyter-core!=5.0.*,>=4.12, but you have jupyter-core 5.0.0 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.1.1 which is incompatible.
# jupyter-server 1.23.6 requires jupyter-core!=5.0.*,>=4.12, but you have jupyter-core 5.0.0 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=5.5.6, but you have ipykernel 6.17.1 which is incompatible.
# google-colab 1.0.0 requires ipython~=7.34.0, but you have ipython 8.6.0 which is incompatible.
# arviz 0.15.1 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# Successfully installed Pillow-9.3.0 Pygments-2.13.0 ascii-graph-1.5.1 asttokens-2.1.0 charset-normalizer-2.1.1 colorama-0.4.6 contourpy-1.0.6 debugpy-1.6.3 decorator-5.1.1 executing-1.2.0 filelock-3.8.0 fire-0.4.0 fonttools-4.38.0 ftfy-6.1.1 huggingface-hub-0.10.1 ipykernel-6.17.1 ipython-8.6.0 jedi-0.18.2 jupyter_client-7.4.7 jupyter_core-5.0.0 matplotlib-3.5.3 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 open-clip-torch-2.4.1 packaging-21.3 patool-1.12 platformdirs-2.5.4 prompt-toolkit-3.0.33 pure-eval-0.2.2 python-fire-0.1.0 pyzmq-24.0.1 requests-2.28.1 scikit-learn-1.0.2 scipy-1.7.3 stack-data-0.6.1 termcolor-2.1.1 torch-1.13.0 torchvision-0.14.0 tqdm-4.64.1 traitlets-5.5.0 typing_extensions-4.4.0 urllib3-1.26.12 wcwidth-0.2.5 wincertstore-0.2

# %% [markdown]
# # Computing Platform Check GPU (CUDA) or CPU / Environment

# %%
#Check Environment And Cuda Version 
from utility.CheckCuda import GetCuda
from utility.envchecker import GetEnvironment

GetCuda()
GetEnvironment()
# Out:
# CUDA version: 11.8
# 'colab'

# %% [markdown]
# # Import the Module/Utility

# %%
import sys
sys.path.insert(0, './image_classifier_pipeline/data_loader/')
sys.path.insert(0, './image_classifier_pipeline/train/')
sys.path.insert(0, './image_classifier_pipeline/classify/')
sys.path.insert(0, './image_classifier_pipeline/model_api/')
from ImageDatasetProcessor import ImageDatasetProcessor
from classify import main as classify_main
from train import main as train_main
from classify_helper_functions import *
from model_api import ModelApi
import patoolib
import shutil

# %% [markdown]
# # Getting Dataset from Mega

# %% [markdown]
# ### Mount Google Drive
# Mount your google drive to be used for storing the dataset into it. Note: This step is optional, the dataset can also be saved to Colab session storage.

# %%
from google.colab import drive
drive.mount._DEBUG = False
drive.mount('/content/drive', force_remount=True)

# %% [markdown]
# ### Mega CMD Installation

# %%
# Mega CMD Requirements
# !apt install libmms0 libc-ares2 libc6 libcrypto++6 libgcc1 libmediainfo0v5 libpcre3 libpcrecpp0v5 libssl1.1 libstdc++6 libzen0v5 zlib1g apt-transport-https
# !apt --fix-broken install

# Mega CMD Download and Installation
# !wget https://mega.nz/linux/MEGAsync/xUbuntu_18.04/amd64/megacmd-xUbuntu_18.04_amd64.deb
# !sudo dpkg -i megacmd-xUbuntu_18.04_amd64.deb
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libc6 is already the newest version (2.31-0ubuntu9.9).
# libpcre3 is already the newest version (2:8.39-12ubuntu0.1).
# libpcrecpp0v5 is already the newest version (2:8.39-12ubuntu0.1).
# libpcrecpp0v5 set to manually installed.
# libssl1.1 is already the newest version (1.1.1f-1ubuntu2.17).
# libssl1.1 set to manually installed.
# libstdc++6 is already the newest version (10.3.0-1ubuntu1~20.04).
# zlib1g is already the newest version (1:1.2.11.dfsg-2ubuntu1.5).
# The following additional packages will be installed:
#   libtinyxml2-6a
# The following NEW packages will be installed:
#   apt-transport-https libc-ares2 libcrypto++6 libgcc1 libmediainfo0v5 libmms0
#   libtinyxml2-6a libzen0v5
# 0 upgraded, 8 newly installed, 0 to remove and 24 not upgraded.
# Need to get 3,271 kB of archives.
# After this operation, 12.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libgcc1 amd64 1:10.3.0-1ubuntu1~20.04 [41.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 apt-transport-https all 2.0.9 [1,704 B]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 libcrypto++6 amd64 5.6.4-9build1 [889 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 libmms0 amd64 0.6.4-3 [27.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/universe amd64 libtinyxml2-6a amd64 7.0.0+dfsg-1build1 [28.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/universe amd64 libzen0v5 amd64 0.4.37-1build1 [97.8 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/universe amd64 libmediainfo0v5 amd64 19.09+dfsg-2build1 [2,149 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libc-ares2 amd64 1.15.0-1ubuntu0.2 [36.7 kB]
# Fetched 3,271 kB in 1s (2,544 kB/s)
# Selecting previously unselected package libgcc1.
# (Reading database ... 122349 files and directories currently installed.)
# Preparing to unpack .../0-libgcc1_1%3a10.3.0-1ubuntu1~20.04_amd64.deb ...
# Unpacking libgcc1 (1:10.3.0-1ubuntu1~20.04) ...
# Selecting previously unselected package apt-transport-https.
# Preparing to unpack .../1-apt-transport-https_2.0.9_all.deb ...
# Unpacking apt-transport-https (2.0.9) ...
# Selecting previously unselected package libcrypto++6.
# Preparing to unpack .../2-libcrypto++6_5.6.4-9build1_amd64.deb ...
# Unpacking libcrypto++6 (5.6.4-9build1) ...
# Selecting previously unselected package libmms0:amd64.
# Preparing to unpack .../3-libmms0_0.6.4-3_amd64.deb ...
# Unpacking libmms0:amd64 (0.6.4-3) ...
# Selecting previously unselected package libtinyxml2-6a:amd64.
# Preparing to unpack .../4-libtinyxml2-6a_7.0.0+dfsg-1build1_amd64.deb ...
# Unpacking libtinyxml2-6a:amd64 (7.0.0+dfsg-1build1) ...
# Selecting previously unselected package libzen0v5:amd64.
# Preparing to unpack .../5-libzen0v5_0.4.37-1build1_amd64.deb ...
# Unpacking libzen0v5:amd64 (0.4.37-1build1) ...
# Selecting previously unselected package libmediainfo0v5:amd64.
# Preparing to unpack .../6-libmediainfo0v5_19.09+dfsg-2build1_amd64.deb ...
# Unpacking libmediainfo0v5:amd64 (19.09+dfsg-2build1) ...
# Selecting previously unselected package libc-ares2:amd64.
# Preparing to unpack .../7-libc-ares2_1.15.0-1ubuntu0.2_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.15.0-1ubuntu0.2) ...
# Setting up apt-transport-https (2.0.9) ...
# Setting up libgcc1 (1:10.3.0-1ubuntu1~20.04) ...
# Setting up libtinyxml2-6a:amd64 (7.0.0+dfsg-1build1) ...
# Setting up libc-ares2:amd64 (1.15.0-1ubuntu0.2) ...
# Setting up libmms0:amd64 (0.6.4-3) ...
# Setting up libzen0v5:amd64 (0.4.37-1build1) ...
# Setting up libmediainfo0v5:amd64 (19.09+dfsg-2build1) ...
# Setting up libcrypto++6 (5.6.4-9build1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# --2023-04-11 20:35:20--  https://mega.nz/linux/MEGAsync/xUbuntu_18.04/amd64/megacmd-xUbuntu_18.04_amd64.deb
# Resolving mega.nz (mega.nz)... 31.216.145.5, 31.216.144.5, 2a0b:e46:1:144::5, ...
# Connecting to mega.nz (mega.nz)|31.216.145.5|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7434374 (7.1M) [application/x-deb]
# Saving to: ‘megacmd-xUbuntu_18.04_amd64.deb’
#
# megacmd-xUbuntu_18. 100%[===================>]   7.09M  5.97MB/s    in 1.2s
#
# 2023-04-11 20:35:22 (5.97 MB/s) - ‘megacmd-xUbuntu_18.04_amd64.deb’ saved [7434374/7434374]
#
# Selecting previously unselected package megacmd.
# (Reading database ... 122389 files and directories currently installed.)
# Preparing to unpack megacmd-xUbuntu_18.04_amd64.deb ...
# Unpacking megacmd (1.5.1-1.1) ...
# Setting up megacmd (1.5.1-1.1) ...
# sysctl: setting key "fs.inotify.max_user_watches", ignoring: Read-only file system

# %% [markdown]
# ### Download Dataset
# Set download URL in Mega and destination path (in Google Drive or session storage) and download the file.

# %%
import os
import contextlib
from subprocess import Popen, PIPE, STDOUT

# Download URL on Mega
tagged_dataset_url = 'https://mega.nz/file/8RhFRISJ#vlQhjBp5hrNtQzFnRVQtD_ilHfIyLOSrlwVXEb3t1UM'
other_dataset_url  = 'https://mega.nz/file/5FhGkRjD#yFihfhr1RMHfPTffhPB4tQtJsnn_HBYFOSfqdPOrp78'
# Destination path for download
destination_path = './downloads'
os.makedirs(destination_path, exist_ok=True)

# Function for printing the download progress
def print_progress(proc, stream='stdout'):
  newlines = ['\n', '\r\n', '\r']
  stream = getattr(proc, stream)
  with contextlib.closing(stream):
      while True:
          out = []
          last = stream.read(1)
          # Don't loop forever
          if last == '' and proc.poll() is not None:
              break
          while last not in newlines:
              # Don't loop forever
              if last == '' and proc.poll() is not None:
                  break
              out.append(last)
              last = stream.read(1)
          out = ''.join(out)
          yield out

# Download dataset
for data_url in [tagged_dataset_url, other_dataset_url]:
  cmd = ["mega-get", data_url, destination_path]
  proc = Popen(cmd,stdout=PIPE, stderr=STDOUT, universal_newlines=True)
  for line in print_progress(proc):
    print(line)
# Out:
# [Initiating MEGAcmd server in background. Log: /root/.megaCmd/megacmdserver.log]
# TRANSFERRING ||#.........................................||(1/929 MB:   0.12 %)
# TRANSFERRING ||#.........................................||(1/929 MB:   0.19 %)
# TRANSFERRING ||#.........................................||(2/929 MB:   0.32 %)
# TRANSFERRING ||#.........................................||(4/929 MB:   0.53 %)
# TRANSFERRING ||#.........................................||(8/929 MB:   0.86 %)
# TRANSFERRING ||#........................................||(10/929 MB:   1.08 %)
# TRANSFERRING ||#........................................||(10/929 MB:   1.12 %)
# TRANSFERRING ||#........................................||(11/929 MB:   1.19 %)
# TRANSFERRING ||#........................................||(11/929 MB:   1.29 %)
# TRANSFERRING ||#........................................||(13/929 MB:   1.42 %)
# TRANSFERRING ||#........................................||(15/929 MB:   1.63 %)
# TRANSFERRING ||#........................................||(18/929 MB:   1.99 %)
# TRANSFERRING ||##.......................................||(23/929 MB:   2.50 %)
# TRANSFERRING ||##.......................................||(29/929 MB:   3.16 %)
# TRANSFERRING ||#........................................||(11/929 MB:   1.25 %)
# TRANSFERRING ||##.......................................||(35/929 MB:   3.78 %)
# TRANSFERRING ||##.......................................||(36/929 MB:   3.95 %)
# TRANSFERRING ||##.......................................||(38/929 MB:   4.10 %)
# TRANSFERRING ||##.......................................||(39/929 MB:   4.20 %)
# TRANSFERRING ||##.......................................||(40/929 MB:   4.31 %)
# TRANSFERRING ||##.......................................||(42/929 MB:   4.61 %)
# TRANSFERRING ||###......................................||(47/929 MB:   5.08 %)
# TRANSFERRING ||###......................................||(49/929 MB:   5.30 %)
# TRANSFERRING ||###......................................||(51/929 MB:   5.49 %)
# TRANSFERRING ||###......................................||(52/929 MB:   5.62 %)
# TRANSFERRING ||###......................................||(52/929 MB:   5.62 %)
# TRANSFERRING ||###......................................||(55/929 MB:   5.95 %)
# TRANSFERRING ||###......................................||(59/929 MB:   6.42 %)
# TRANSFERRING ||###......................................||(61/929 MB:   6.57 %)
# TRANSFERRING ||###......................................||(61/929 MB:   6.58 %)
# TRANSFERRING ||###......................................||(61/929 MB:   6.59 %)
# TRANSFERRING ||###......................................||(61/929 MB:   6.61 %)
# TRANSFERRING ||###......................................||(61/929 MB:   6.66 %)
# TRANSFERRING ||###......................................||(62/929 MB:   6.73 %)
# TRANSFERRING ||###......................................||(63/929 MB:   6.88 %)
# TRANSFERRING ||##.......................................||(43/929 MB:   4.69 %)
# TRANSFERRING ||####.....................................||(70/929 MB:   7.60 %)
# TRANSFERRING ||####.....................................||(74/929 MB:   8.00 %)
# TRANSFERRING ||####.....................................||(78/929 MB:   8.48 %)
# TRANSFERRING ||####.....................................||(84/929 MB:   9.05 %)
# TRANSFERRING ||####.....................................||(86/929 MB:   9.35 %)
# TRANSFERRING ||###......................................||(65/929 MB:   7.05 %)
# TRANSFERRING ||####.....................................||(88/929 MB:   9.50 %)
# TRANSFERRING ||#####....................................||(90/929 MB:   9.79 %)
# TRANSFERRING ||#####....................................||(92/929 MB:   9.95 %)
# TRANSFERRING ||#####....................................||(94/929 MB:  10.17 %)
# TRANSFERRING ||#####...................................||(103/929 MB:  11.09 %)
# TRANSFERRING ||#####...................................||(111/929 MB:  12.00 %)
# TRANSFERRING ||#####....................................||(91/929 MB:   9.88 %)
# TRANSFERRING ||#####...................................||(112/929 MB:  12.14 %)
# TRANSFERRING ||#####...................................||(113/929 MB:  12.20 %)
# TRANSFERRING ||#####...................................||(114/929 MB:  12.31 %)
# TRANSFERRING ||#####...................................||(115/929 MB:  12.46 %)
# TRANSFERRING ||######..................................||(116/929 MB:  12.54 %)
# TRANSFERRING ||######..................................||(118/929 MB:  12.74 %)
# TRANSFERRING ||######..................................||(126/929 MB:  13.64 %)
# TRANSFERRING ||######..................................||(134/929 MB:  14.44 %)
# TRANSFERRING ||######..................................||(135/929 MB:  14.55 %)
# TRANSFERRING ||#####...................................||(114/929 MB:  12.28 %)
# TRANSFERRING ||######..................................||(137/929 MB:  14.73 %)
# TRANSFERRING ||######..................................||(137/929 MB:  14.83 %)
# TRANSFERRING ||######..................................||(138/929 MB:  14.93 %)
# TRANSFERRING ||######..................................||(139/929 MB:  14.98 %)
# TRANSFERRING ||#######.................................||(139/929 MB:  15.02 %)
# TRANSFERRING ||#######.................................||(147/929 MB:  15.81 %)
# TRANSFERRING ||#######.................................||(153/929 MB:  16.46 %)
# TRANSFERRING ||######..................................||(133/929 MB:  14.41 %)
# TRANSFERRING ||#######.................................||(156/929 MB:  16.87 %)
# TRANSFERRING ||#######.................................||(157/929 MB:  16.91 %)
# TRANSFERRING ||#######.................................||(157/929 MB:  16.98 %)
# TRANSFERRING ||#######.................................||(158/929 MB:  17.06 %)
# TRANSFERRING ||#######.................................||(159/929 MB:  17.14 %)
# TRANSFERRING ||#######.................................||(161/929 MB:  17.32 %)
# TRANSFERRING ||########................................||(171/929 MB:  18.48 %)
# TRANSFERRING ||########................................||(178/929 MB:  19.22 %)
# TRANSFERRING ||########................................||(178/929 MB:  19.24 %)
# TRANSFERRING ||########................................||(178/929 MB:  19.24 %)
# TRANSFERRING ||########................................||(180/929 MB:  19.44 %)
# TRANSFERRING ||########................................||(183/929 MB:  19.71 %)
# TRANSFERRING ||########................................||(184/929 MB:  19.82 %)
# TRANSFERRING ||#########...............................||(187/929 MB:  20.17 %)
# TRANSFERRING ||#########...............................||(194/929 MB:  20.94 %)
# TRANSFERRING ||#########...............................||(200/929 MB:  21.54 %)
# TRANSFERRING ||########................................||(178/929 MB:  19.24 %)
# TRANSFERRING ||#########...............................||(200/929 MB:  21.60 %)
# TRANSFERRING ||#########...............................||(200/929 MB:  21.61 %)
# TRANSFERRING ||#########...............................||(200/929 MB:  21.62 %)
# TRANSFERRING ||#########...............................||(202/929 MB:  21.80 %)
# TRANSFERRING ||##########..............................||(209/929 MB:  22.53 %)
# TRANSFERRING ||##########..............................||(215/929 MB:  23.15 %)
# TRANSFERRING ||##########..............................||(217/929 MB:  23.35 %)
# TRANSFERRING ||##########..............................||(217/929 MB:  23.44 %)
# TRANSFERRING ||##########..............................||(218/929 MB:  23.50 %)
# TRANSFERRING ||##########..............................||(218/929 MB:  23.50 %)
# TRANSFERRING ||##########..............................||(218/929 MB:  23.51 %)
# TRANSFERRING ||##########..............................||(219/929 MB:  23.58 %)
# TRANSFERRING ||##########..............................||(220/929 MB:  23.76 %)
# TRANSFERRING ||##########..............................||(229/929 MB:  24.66 %)
# TRANSFERRING ||###########.............................||(237/929 MB:  25.51 %)
# TRANSFERRING ||###########.............................||(237/929 MB:  25.59 %)
# TRANSFERRING ||###########.............................||(238/929 MB:  25.61 %)
# TRANSFERRING ||###########.............................||(240/929 MB:  25.86 %)
# TRANSFERRING ||###########.............................||(242/929 MB:  26.13 %)
# TRANSFERRING ||###########.............................||(243/929 MB:  26.17 %)
# TRANSFERRING ||###########.............................||(243/929 MB:  26.21 %)
# TRANSFERRING ||###########.............................||(244/929 MB:  26.26 %)
# TRANSFERRING ||###########.............................||(245/929 MB:  26.36 %)
# TRANSFERRING ||##########..............................||(230/929 MB:  24.78 %)
# TRANSFERRING ||############............................||(255/929 MB:  27.53 %)
# TRANSFERRING ||############............................||(257/929 MB:  27.74 %)
# TRANSFERRING ||############............................||(258/929 MB:  27.79 %)
# TRANSFERRING ||############............................||(258/929 MB:  27.85 %)
# TRANSFERRING ||############............................||(259/929 MB:  27.90 %)
# TRANSFERRING ||############............................||(259/929 MB:  27.94 %)
# TRANSFERRING ||############............................||(260/929 MB:  27.97 %)
# TRANSFERRING ||############............................||(260/929 MB:  28.01 %)
# TRANSFERRING ||############............................||(261/929 MB:  28.09 %)
# TRANSFERRING ||############............................||(268/929 MB:  28.83 %)
# TRANSFERRING ||############............................||(273/929 MB:  29.46 %)
# TRANSFERRING ||############............................||(274/929 MB:  29.55 %)
# TRANSFERRING ||############............................||(275/929 MB:  29.59 %)
# TRANSFERRING ||############............................||(275/929 MB:  29.62 %)
# TRANSFERRING ||############............................||(275/929 MB:  29.64 %)
# TRANSFERRING ||############............................||(275/929 MB:  29.64 %)
# TRANSFERRING ||############............................||(275/929 MB:  29.68 %)
# TRANSFERRING ||############............................||(276/929 MB:  29.74 %)
# TRANSFERRING ||############............................||(277/929 MB:  29.81 %)
# TRANSFERRING ||############............................||(277/929 MB:  29.86 %)
# TRANSFERRING ||############............................||(278/929 MB:  29.92 %)
# TRANSFERRING ||############............................||(278/929 MB:  29.98 %)
# TRANSFERRING ||#############...........................||(279/929 MB:  30.04 %)
# TRANSFERRING ||#############...........................||(280/929 MB:  30.12 %)
# TRANSFERRING ||#############...........................||(280/929 MB:  30.16 %)
# TRANSFERRING ||#############...........................||(280/929 MB:  30.19 %)
# TRANSFERRING ||#############...........................||(281/929 MB:  30.26 %)
# TRANSFERRING ||#############...........................||(282/929 MB:  30.37 %)
# TRANSFERRING ||############............................||(262/929 MB:  28.27 %)
# TRANSFERRING ||############............................||(263/929 MB:  28.32 %)
# TRANSFERRING ||#############...........................||(285/929 MB:  30.75 %)
# TRANSFERRING ||#############...........................||(289/929 MB:  31.08 %)
# TRANSFERRING ||#############...........................||(290/929 MB:  31.23 %)
# TRANSFERRING ||#############...........................||(290/929 MB:  31.29 %)
# TRANSFERRING ||#############...........................||(291/929 MB:  31.36 %)
# TRANSFERRING ||#############...........................||(292/929 MB:  31.43 %)
# TRANSFERRING ||#############...........................||(293/929 MB:  31.53 %)
# TRANSFERRING ||#############...........................||(300/929 MB:  32.35 %)
# TRANSFERRING ||##############..........................||(308/929 MB:  33.21 %)
# TRANSFERRING ||##############..........................||(310/929 MB:  33.43 %)
# TRANSFERRING ||#############...........................||(289/929 MB:  31.13 %)
# TRANSFERRING ||##############..........................||(313/929 MB:  33.75 %)
# TRANSFERRING ||##############..........................||(316/929 MB:  34.07 %)
# TRANSFERRING ||##############..........................||(317/929 MB:  34.15 %)
# TRANSFERRING ||##############..........................||(317/929 MB:  34.19 %)
# TRANSFERRING ||##############..........................||(318/929 MB:  34.25 %)
# TRANSFERRING ||##############..........................||(319/929 MB:  34.39 %)
# TRANSFERRING ||##############..........................||(325/929 MB:  34.97 %)
# TRANSFERRING ||###############.........................||(330/929 MB:  35.54 %)
# TRANSFERRING ||###############.........................||(332/929 MB:  35.71 %)
# TRANSFERRING ||##############..........................||(310/929 MB:  33.42 %)
# TRANSFERRING ||###############.........................||(333/929 MB:  35.84 %)
# TRANSFERRING ||###############.........................||(333/929 MB:  35.88 %)
# TRANSFERRING ||###############.........................||(334/929 MB:  35.95 %)
# TRANSFERRING ||###############.........................||(334/929 MB:  36.00 %)
# TRANSFERRING ||###############.........................||(335/929 MB:  36.06 %)
# TRANSFERRING ||###############.........................||(336/929 MB:  36.15 %)
# TRANSFERRING ||###############.........................||(340/929 MB:  36.64 %)
# TRANSFERRING ||###############.........................||(347/929 MB:  37.38 %)
# TRANSFERRING ||################........................||(349/929 MB:  37.58 %)
# TRANSFERRING ||###############.........................||(327/929 MB:  35.25 %)
# TRANSFERRING ||################........................||(350/929 MB:  37.72 %)
# TRANSFERRING ||################........................||(353/929 MB:  37.98 %)
# TRANSFERRING ||################........................||(355/929 MB:  38.23 %)
# TRANSFERRING ||################........................||(355/929 MB:  38.27 %)
# TRANSFERRING ||################........................||(356/929 MB:  38.32 %)
# TRANSFERRING ||################........................||(357/929 MB:  38.43 %)
# TRANSFERRING ||################........................||(365/929 MB:  39.34 %)
# TRANSFERRING ||#################.......................||(373/929 MB:  40.21 %)
# TRANSFERRING ||#################.......................||(375/929 MB:  40.36 %)
# TRANSFERRING ||#################.......................||(375/929 MB:  40.40 %)
# TRANSFERRING ||#################.......................||(375/929 MB:  40.43 %)
# TRANSFERRING ||#################.......................||(375/929 MB:  40.43 %)
# TRANSFERRING ||#################.......................||(376/929 MB:  40.50 %)
# TRANSFERRING ||#################.......................||(384/929 MB:  41.34 %)
# TRANSFERRING ||#################.......................||(389/929 MB:  41.90 %)
# TRANSFERRING ||#################.......................||(389/929 MB:  41.94 %)
# TRANSFERRING ||#################.......................||(390/929 MB:  41.97 %)
# TRANSFERRING ||#################.......................||(390/929 MB:  42.01 %)
# TRANSFERRING ||#################.......................||(390/929 MB:  42.04 %)
# TRANSFERRING ||#################.......................||(391/929 MB:  42.06 %)
# TRANSFERRING ||#################.......................||(391/929 MB:  42.09 %)
# TRANSFERRING ||#################.......................||(391/929 MB:  42.11 %)
# TRANSFERRING ||#################.......................||(392/929 MB:  42.21 %)
# TRANSFERRING ||##################......................||(399/929 MB:  43.00 %)
# TRANSFERRING ||##################......................||(405/929 MB:  43.58 %)
# TRANSFERRING ||##################......................||(405/929 MB:  43.60 %)
# TRANSFERRING ||##################......................||(405/929 MB:  43.62 %)
# TRANSFERRING ||##################......................||(405/929 MB:  43.65 %)
# TRANSFERRING ||##################......................||(406/929 MB:  43.67 %)
# TRANSFERRING ||##################......................||(406/929 MB:  43.70 %)
# TRANSFERRING ||##################......................||(406/929 MB:  43.73 %)
# TRANSFERRING ||##################......................||(406/929 MB:  43.73 %)
# TRANSFERRING ||##################......................||(406/929 MB:  43.76 %)
# TRANSFERRING ||##################......................||(407/929 MB:  43.80 %)
# TRANSFERRING ||##################......................||(407/929 MB:  43.83 %)
# TRANSFERRING ||##################......................||(407/929 MB:  43.86 %)
# TRANSFERRING ||##################......................||(408/929 MB:  43.90 %)
# TRANSFERRING ||##################......................||(408/929 MB:  43.94 %)
# TRANSFERRING ||##################......................||(409/929 MB:  44.00 %)
# TRANSFERRING ||##################......................||(409/929 MB:  44.05 %)
# TRANSFERRING ||##################......................||(410/929 MB:  44.14 %)
# TRANSFERRING ||##################......................||(411/929 MB:  44.28 %)
# TRANSFERRING ||##################......................||(413/929 MB:  44.52 %)
# TRANSFERRING ||##################......................||(414/929 MB:  44.56 %)
# TRANSFERRING ||##################......................||(415/929 MB:  44.68 %)
# TRANSFERRING ||##################......................||(418/929 MB:  44.97 %)
# TRANSFERRING ||###################.....................||(419/929 MB:  45.13 %)
# TRANSFERRING ||###################.....................||(419/929 MB:  45.16 %)
# TRANSFERRING ||###################.....................||(419/929 MB:  45.16 %)
# TRANSFERRING ||###################.....................||(419/929 MB:  45.16 %)
# TRANSFERRING ||###################.....................||(422/929 MB:  45.42 %)
# TRANSFERRING ||###################.....................||(426/929 MB:  45.87 %)
# TRANSFERRING ||###################.....................||(429/929 MB:  46.18 %)
# TRANSFERRING ||###################.....................||(429/929 MB:  46.21 %)
# TRANSFERRING ||###################.....................||(429/929 MB:  46.24 %)
# TRANSFERRING ||###################.....................||(430/929 MB:  46.27 %)
# TRANSFERRING ||###################.....................||(430/929 MB:  46.32 %)
# TRANSFERRING ||###################.....................||(431/929 MB:  46.39 %)
# TRANSFERRING ||###################.....................||(432/929 MB:  46.47 %)
# TRANSFERRING ||###################.....................||(433/929 MB:  46.63 %)
# TRANSFERRING ||###################.....................||(441/929 MB:  47.44 %)
# TRANSFERRING ||####################....................||(444/929 MB:  47.79 %)
# TRANSFERRING ||####################....................||(444/929 MB:  47.82 %)
# TRANSFERRING ||####################....................||(444/929 MB:  47.85 %)
# TRANSFERRING ||####################....................||(445/929 MB:  47.87 %)
# TRANSFERRING ||####################....................||(445/929 MB:  47.90 %)
# TRANSFERRING ||####################....................||(445/929 MB:  47.93 %)
# TRANSFERRING ||####################....................||(445/929 MB:  47.96 %)
# TRANSFERRING ||####################....................||(446/929 MB:  47.99 %)
# TRANSFERRING ||####################....................||(446/929 MB:  48.07 %)
# TRANSFERRING ||####################....................||(449/929 MB:  48.36 %)
# TRANSFERRING ||####################....................||(451/929 MB:  48.55 %)
# TRANSFERRING ||####################....................||(453/929 MB:  48.81 %)
# TRANSFERRING ||####################....................||(455/929 MB:  48.98 %)
# TRANSFERRING ||####################....................||(455/929 MB:  49.01 %)
# TRANSFERRING ||####################....................||(455/929 MB:  49.03 %)
# TRANSFERRING ||####################....................||(456/929 MB:  49.05 %)
# TRANSFERRING ||####################....................||(456/929 MB:  49.08 %)
# TRANSFERRING ||####################....................||(456/929 MB:  49.10 %)
# TRANSFERRING ||####################....................||(458/929 MB:  49.31 %)
# TRANSFERRING ||####################....................||(463/929 MB:  49.85 %)
# TRANSFERRING ||#####################...................||(465/929 MB:  50.10 %)
# TRANSFERRING ||#####################...................||(466/929 MB:  50.13 %)
# TRANSFERRING ||#####################...................||(466/929 MB:  50.16 %)
# TRANSFERRING ||#####################...................||(466/929 MB:  50.17 %)
# TRANSFERRING ||#####################...................||(466/929 MB:  50.19 %)
# TRANSFERRING ||#####################...................||(466/929 MB:  50.21 %)
# TRANSFERRING ||#####################...................||(467/929 MB:  50.23 %)
# TRANSFERRING ||#####################...................||(467/929 MB:  50.24 %)
# TRANSFERRING ||#####################...................||(467/929 MB:  50.26 %)
# TRANSFERRING ||#####################...................||(467/929 MB:  50.29 %)
# TRANSFERRING ||#####################...................||(467/929 MB:  50.30 %)
# TRANSFERRING ||#####################...................||(467/929 MB:  50.32 %)
# TRANSFERRING ||#####################...................||(468/929 MB:  50.34 %)
# TRANSFERRING ||#####################...................||(467/929 MB:  50.25 %)
# TRANSFERRING ||#####################...................||(467/929 MB:  50.30 %)
# TRANSFERRING ||#####################...................||(469/929 MB:  50.49 %)
# TRANSFERRING ||#####################...................||(469/929 MB:  50.52 %)
# TRANSFERRING ||#####################...................||(469/929 MB:  50.54 %)
# TRANSFERRING ||#####################...................||(470/929 MB:  50.58 %)
# TRANSFERRING ||#####################...................||(471/929 MB:  50.75 %)
# TRANSFERRING ||#####################...................||(473/929 MB:  50.94 %)
# TRANSFERRING ||#####################...................||(474/929 MB:  51.00 %)
# TRANSFERRING ||#####################...................||(474/929 MB:  51.07 %)
# TRANSFERRING ||#####################...................||(475/929 MB:  51.16 %)
# TRANSFERRING ||#####################...................||(477/929 MB:  51.33 %)
# TRANSFERRING ||#####################...................||(481/929 MB:  51.76 %)
# TRANSFERRING ||#####################...................||(482/929 MB:  51.94 %)
# TRANSFERRING ||#####################...................||(483/929 MB:  51.96 %)
# TRANSFERRING ||#####################...................||(483/929 MB:  51.97 %)
# TRANSFERRING ||#####################...................||(483/929 MB:  51.99 %)
# TRANSFERRING ||#####################...................||(483/929 MB:  52.00 %)
# TRANSFERRING ||#####################...................||(483/929 MB:  52.02 %)
# TRANSFERRING ||#####################...................||(483/929 MB:  52.04 %)
# TRANSFERRING ||#####################...................||(483/929 MB:  52.05 %)
# TRANSFERRING ||#####################...................||(486/929 MB:  52.33 %)
# TRANSFERRING ||######################..................||(488/929 MB:  52.56 %)
# TRANSFERRING ||######################..................||(488/929 MB:  52.57 %)
# TRANSFERRING ||######################..................||(489/929 MB:  52.59 %)
# TRANSFERRING ||######################..................||(489/929 MB:  52.62 %)
# TRANSFERRING ||######################..................||(489/929 MB:  52.62 %)
# TRANSFERRING ||######################..................||(489/929 MB:  52.63 %)
# TRANSFERRING ||######################..................||(489/929 MB:  52.65 %)
# TRANSFERRING ||######################..................||(490/929 MB:  52.76 %)
# TRANSFERRING ||######################..................||(492/929 MB:  53.01 %)
# TRANSFERRING ||######################..................||(494/929 MB:  53.17 %)
# TRANSFERRING ||######################..................||(494/929 MB:  53.20 %)
# TRANSFERRING ||######################..................||(494/929 MB:  53.22 %)
# TRANSFERRING ||######################..................||(495/929 MB:  53.25 %)
# TRANSFERRING ||######################..................||(495/929 MB:  53.28 %)
# TRANSFERRING ||######################..................||(495/929 MB:  53.34 %)
# TRANSFERRING ||######################..................||(496/929 MB:  53.43 %)
# TRANSFERRING ||######################..................||(498/929 MB:  53.59 %)
# TRANSFERRING ||######################..................||(500/929 MB:  53.83 %)
# TRANSFERRING ||######################..................||(503/929 MB:  54.15 %)
# TRANSFERRING ||######################..................||(505/929 MB:  54.32 %)
# TRANSFERRING ||######################..................||(505/929 MB:  54.34 %)
# TRANSFERRING ||######################..................||(505/929 MB:  54.36 %)
# TRANSFERRING ||######################..................||(507/929 MB:  54.59 %)
# TRANSFERRING ||######################..................||(509/929 MB:  54.83 %)
# TRANSFERRING ||######################..................||(510/929 MB:  54.87 %)
# TRANSFERRING ||######################..................||(510/929 MB:  54.89 %)
# TRANSFERRING ||######################..................||(510/929 MB:  54.92 %)
# TRANSFERRING ||######################..................||(510/929 MB:  54.94 %)
# TRANSFERRING ||######################..................||(511/929 MB:  54.97 %)
# TRANSFERRING ||######################..................||(511/929 MB:  54.98 %)
# TRANSFERRING ||######################..................||(511/929 MB:  54.99 %)
# TRANSFERRING ||######################..................||(511/929 MB:  55.00 %)
# TRANSFERRING ||#######################.................||(511/929 MB:  55.01 %)
# TRANSFERRING ||#######################.................||(511/929 MB:  55.02 %)
# TRANSFERRING ||#######################.................||(511/929 MB:  55.03 %)
# TRANSFERRING ||#######################.................||(511/929 MB:  55.04 %)
# TRANSFERRING ||#######################.................||(511/929 MB:  55.05 %)
# TRANSFERRING ||#######################.................||(514/929 MB:  55.30 %)
# TRANSFERRING ||#######################.................||(516/929 MB:  55.55 %)
# TRANSFERRING ||#######################.................||(516/929 MB:  55.56 %)
# TRANSFERRING ||#######################.................||(516/929 MB:  55.58 %)
# TRANSFERRING ||#######################.................||(516/929 MB:  55.60 %)
# TRANSFERRING ||#######################.................||(517/929 MB:  55.62 %)
# TRANSFERRING ||#######################.................||(517/929 MB:  55.65 %)
# TRANSFERRING ||#######################.................||(517/929 MB:  55.68 %)
# TRANSFERRING ||#######################.................||(518/929 MB:  55.72 %)
# TRANSFERRING ||#######################.................||(518/929 MB:  55.78 %)
# TRANSFERRING ||#######################.................||(522/929 MB:  56.20 %)
# TRANSFERRING ||#######################.................||(525/929 MB:  56.47 %)
# TRANSFERRING ||#######################.................||(526/929 MB:  56.61 %)
# TRANSFERRING ||#######################.................||(526/929 MB:  56.62 %)
# TRANSFERRING ||#######################.................||(526/929 MB:  56.63 %)
# TRANSFERRING ||#######################.................||(526/929 MB:  56.64 %)
# TRANSFERRING ||#######################.................||(526/929 MB:  56.65 %)
# TRANSFERRING ||#######################.................||(526/929 MB:  56.66 %)
# TRANSFERRING ||#######################.................||(526/929 MB:  56.67 %)
# TRANSFERRING ||#######################.................||(527/929 MB:  56.69 %)
# TRANSFERRING ||#######################.................||(528/929 MB:  56.84 %)
# TRANSFERRING ||#######################.................||(530/929 MB:  57.05 %)
# TRANSFERRING ||#######################.................||(531/929 MB:  57.18 %)
# TRANSFERRING ||#######################.................||(531/929 MB:  57.20 %)
# TRANSFERRING ||#######################.................||(531/929 MB:  57.21 %)
# TRANSFERRING ||#######################.................||(531/929 MB:  57.22 %)
# TRANSFERRING ||#######################.................||(532/929 MB:  57.23 %)
# TRANSFERRING ||#######################.................||(532/929 MB:  57.24 %)
# TRANSFERRING ||#######################.................||(532/929 MB:  57.25 %)
# TRANSFERRING ||#######################.................||(532/929 MB:  57.26 %)
# TRANSFERRING ||#######################.................||(532/929 MB:  57.27 %)
# TRANSFERRING ||#######################.................||(532/929 MB:  57.28 %)
# TRANSFERRING ||#######################.................||(532/929 MB:  57.29 %)
# TRANSFERRING ||#######################.................||(532/929 MB:  57.30 %)
# TRANSFERRING ||#######################.................||(532/929 MB:  57.31 %)
# TRANSFERRING ||#######################.................||(532/929 MB:  57.32 %)
# TRANSFERRING ||#######################.................||(533/929 MB:  57.33 %)
# TRANSFERRING ||#######################.................||(533/929 MB:  57.35 %)
# TRANSFERRING ||#######################.................||(533/929 MB:  57.39 %)
# TRANSFERRING ||########################................||(535/929 MB:  57.57 %)
# TRANSFERRING ||########################................||(537/929 MB:  57.85 %)
# TRANSFERRING ||########################................||(538/929 MB:  57.87 %)
# TRANSFERRING ||########################................||(538/929 MB:  57.89 %)
# TRANSFERRING ||########################................||(538/929 MB:  57.91 %)
# TRANSFERRING ||########################................||(538/929 MB:  57.94 %)
# TRANSFERRING ||########################................||(539/929 MB:  57.98 %)
# TRANSFERRING ||########################................||(539/929 MB:  58.05 %)
# TRANSFERRING ||########################................||(540/929 MB:  58.18 %)
# TRANSFERRING ||########################................||(545/929 MB:  58.66 %)
# TRANSFERRING ||########################................||(547/929 MB:  58.91 %)
# TRANSFERRING ||########################................||(547/929 MB:  58.92 %)
# TRANSFERRING ||########################................||(550/929 MB:  59.17 %)
# TRANSFERRING ||########################................||(552/929 MB:  59.40 %)
# TRANSFERRING ||########################................||(552/929 MB:  59.44 %)
# TRANSFERRING ||########################................||(552/929 MB:  59.45 %)
# TRANSFERRING ||########################................||(552/929 MB:  59.47 %)
# TRANSFERRING ||########################................||(553/929 MB:  59.48 %)
# TRANSFERRING ||########################................||(553/929 MB:  59.50 %)
# TRANSFERRING ||########################................||(553/929 MB:  59.51 %)
# TRANSFERRING ||########################................||(553/929 MB:  59.53 %)
# TRANSFERRING ||########################................||(553/929 MB:  59.55 %)
# TRANSFERRING ||########################................||(553/929 MB:  59.56 %)
# TRANSFERRING ||########################................||(553/929 MB:  59.58 %)
# TRANSFERRING ||########################................||(554/929 MB:  59.60 %)
# TRANSFERRING ||########################................||(554/929 MB:  59.62 %)
# TRANSFERRING ||########################................||(554/929 MB:  59.64 %)
# TRANSFERRING ||########################................||(554/929 MB:  59.65 %)
# TRANSFERRING ||########################................||(554/929 MB:  59.67 %)
# TRANSFERRING ||########################................||(554/929 MB:  59.68 %)
# TRANSFERRING ||########################................||(555/929 MB:  59.70 %)
# TRANSFERRING ||########################................||(555/929 MB:  59.72 %)
# TRANSFERRING ||########################................||(555/929 MB:  59.73 %)
# TRANSFERRING ||########################................||(555/929 MB:  59.75 %)
# TRANSFERRING ||########################................||(555/929 MB:  59.77 %)
# TRANSFERRING ||########################................||(555/929 MB:  59.79 %)
# TRANSFERRING ||########################................||(556/929 MB:  59.82 %)
# TRANSFERRING ||########################................||(557/929 MB:  59.96 %)
# TRANSFERRING ||#########################...............||(559/929 MB:  60.13 %)
# TRANSFERRING ||#########################...............||(560/929 MB:  60.33 %)
# TRANSFERRING ||#########################...............||(561/929 MB:  60.35 %)
# TRANSFERRING ||#########################...............||(561/929 MB:  60.38 %)
# TRANSFERRING ||#########################...............||(561/929 MB:  60.42 %)
# TRANSFERRING ||#########################...............||(562/929 MB:  60.47 %)
# TRANSFERRING ||#########################...............||(562/929 MB:  60.53 %)
# TRANSFERRING ||#########################...............||(563/929 MB:  60.59 %)
# TRANSFERRING ||#########################...............||(564/929 MB:  60.70 %)
# TRANSFERRING ||#########################...............||(567/929 MB:  60.98 %)
# TRANSFERRING ||#########################...............||(569/929 MB:  61.23 %)
# TRANSFERRING ||#########################...............||(571/929 MB:  61.46 %)
# TRANSFERRING ||#########################...............||(574/929 MB:  61.80 %)
# TRANSFERRING ||#########################...............||(576/929 MB:  61.95 %)
# TRANSFERRING ||#########################...............||(576/929 MB:  61.97 %)
# TRANSFERRING ||#########################...............||(576/929 MB:  61.99 %)
# TRANSFERRING ||#########################...............||(576/929 MB:  62.01 %)
# TRANSFERRING ||#########################...............||(576/929 MB:  62.03 %)
# TRANSFERRING ||#########################...............||(576/929 MB:  62.03 %)
# TRANSFERRING ||#########################...............||(576/929 MB:  62.03 %)
# TRANSFERRING ||#########################...............||(576/929 MB:  62.03 %)
# TRANSFERRING ||#########################...............||(576/929 MB:  62.04 %)
# TRANSFERRING ||#########################...............||(576/929 MB:  62.05 %)
# TRANSFERRING ||#########################...............||(577/929 MB:  62.08 %)
# TRANSFERRING ||#########################...............||(577/929 MB:  62.08 %)
# TRANSFERRING ||#########################...............||(577/929 MB:  62.09 %)
# TRANSFERRING ||#########################...............||(577/929 MB:  62.10 %)
# TRANSFERRING ||#########################...............||(578/929 MB:  62.19 %)
# TRANSFERRING ||#########################...............||(579/929 MB:  62.34 %)
# TRANSFERRING ||#########################...............||(580/929 MB:  62.48 %)
# TRANSFERRING ||##########################..............||(582/929 MB:  62.63 %)
# TRANSFERRING ||##########################..............||(582/929 MB:  62.66 %)
# TRANSFERRING ||##########################..............||(582/929 MB:  62.68 %)
# TRANSFERRING ||##########################..............||(583/929 MB:  62.72 %)
# TRANSFERRING ||##########################..............||(583/929 MB:  62.76 %)
# TRANSFERRING ||##########################..............||(584/929 MB:  62.83 %)
# TRANSFERRING ||##########################..............||(585/929 MB:  62.94 %)
# TRANSFERRING ||##########################..............||(587/929 MB:  63.22 %)
# TRANSFERRING ||##########################..............||(591/929 MB:  63.56 %)
# TRANSFERRING ||##########################..............||(592/929 MB:  63.73 %)
# TRANSFERRING ||##########################..............||(595/929 MB:  64.06 %)
# TRANSFERRING ||##########################..............||(597/929 MB:  64.24 %)
# TRANSFERRING ||##########################..............||(597/929 MB:  64.25 %)
# TRANSFERRING ||##########################..............||(597/929 MB:  64.27 %)
# TRANSFERRING ||##########################..............||(597/929 MB:  64.28 %)
# TRANSFERRING ||##########################..............||(597/929 MB:  64.31 %)
# TRANSFERRING ||##########################..............||(598/929 MB:  64.33 %)
# TRANSFERRING ||##########################..............||(598/929 MB:  64.35 %)
# TRANSFERRING ||##########################..............||(598/929 MB:  64.38 %)
# TRANSFERRING ||##########################..............||(598/929 MB:  64.41 %)
# TRANSFERRING ||##########################..............||(599/929 MB:  64.45 %)
# TRANSFERRING ||##########################..............||(599/929 MB:  64.45 %)
# TRANSFERRING ||##########################..............||(599/929 MB:  64.47 %)
# TRANSFERRING ||##########################..............||(599/929 MB:  64.48 %)
# TRANSFERRING ||##########################..............||(599/929 MB:  64.50 %)
# TRANSFERRING ||##########################..............||(599/929 MB:  64.52 %)
# TRANSFERRING ||##########################..............||(603/929 MB:  64.86 %)
# TRANSFERRING ||###########################.............||(604/929 MB:  65.03 %)
# TRANSFERRING ||###########################.............||(604/929 MB:  65.05 %)
# TRANSFERRING ||###########################.............||(605/929 MB:  65.08 %)
# TRANSFERRING ||###########################.............||(605/929 MB:  65.11 %)
# TRANSFERRING ||###########################.............||(605/929 MB:  65.14 %)
# TRANSFERRING ||###########################.............||(606/929 MB:  65.18 %)
# TRANSFERRING ||###########################.............||(606/929 MB:  65.21 %)
# TRANSFERRING ||###########################.............||(606/929 MB:  65.25 %)
# TRANSFERRING ||###########################.............||(607/929 MB:  65.31 %)
# TRANSFERRING ||###########################.............||(610/929 MB:  65.64 %)
# TRANSFERRING ||###########################.............||(613/929 MB:  65.99 %)
# TRANSFERRING ||###########################.............||(615/929 MB:  66.18 %)
# TRANSFERRING ||###########################.............||(615/929 MB:  66.21 %)
# TRANSFERRING ||###########################.............||(615/929 MB:  66.24 %)
# TRANSFERRING ||###########################.............||(616/929 MB:  66.27 %)
# TRANSFERRING ||###########################.............||(616/929 MB:  66.30 %)
# TRANSFERRING ||###########################.............||(616/929 MB:  66.32 %)
# TRANSFERRING ||###########################.............||(616/929 MB:  66.34 %)
# TRANSFERRING ||###########################.............||(616/929 MB:  66.36 %)
# TRANSFERRING ||###########################.............||(618/929 MB:  66.53 %)
# TRANSFERRING ||###########################.............||(622/929 MB:  67.00 %)
# TRANSFERRING ||###########################.............||(627/929 MB:  67.46 %)
# TRANSFERRING ||############################............||(628/929 MB:  67.56 %)
# TRANSFERRING ||############################............||(629/929 MB:  67.68 %)
# TRANSFERRING ||############################............||(631/929 MB:  67.94 %)
# TRANSFERRING ||############################............||(635/929 MB:  68.35 %)
# TRANSFERRING ||############################............||(635/929 MB:  68.36 %)
# TRANSFERRING ||############################............||(635/929 MB:  68.38 %)
# TRANSFERRING ||############################............||(636/929 MB:  68.48 %)
# TRANSFERRING ||############################............||(640/929 MB:  68.85 %)
# TRANSFERRING ||############################............||(643/929 MB:  69.26 %)
# TRANSFERRING ||############################............||(645/929 MB:  69.40 %)
# TRANSFERRING ||############################............||(645/929 MB:  69.42 %)
# TRANSFERRING ||############################............||(645/929 MB:  69.44 %)
# TRANSFERRING ||############################............||(645/929 MB:  69.46 %)
# TRANSFERRING ||############################............||(646/929 MB:  69.48 %)
# TRANSFERRING ||############################............||(646/929 MB:  69.50 %)
# TRANSFERRING ||############################............||(646/929 MB:  69.52 %)
# TRANSFERRING ||############################............||(646/929 MB:  69.53 %)
# TRANSFERRING ||############################............||(646/929 MB:  69.55 %)
# TRANSFERRING ||############################............||(646/929 MB:  69.56 %)
# TRANSFERRING ||############################............||(646/929 MB:  69.58 %)
# TRANSFERRING ||############################............||(647/929 MB:  69.60 %)
# TRANSFERRING ||############################............||(647/929 MB:  69.62 %)
# TRANSFERRING ||############################............||(647/929 MB:  69.64 %)
# TRANSFERRING ||############################............||(646/929 MB:  69.54 %)
# TRANSFERRING ||############################............||(646/929 MB:  69.56 %)
# TRANSFERRING ||############################............||(646/929 MB:  69.58 %)
# TRANSFERRING ||############################............||(647/929 MB:  69.60 %)
# TRANSFERRING ||############################............||(647/929 MB:  69.62 %)
# TRANSFERRING ||############################............||(647/929 MB:  69.65 %)
# TRANSFERRING ||############################............||(647/929 MB:  69.68 %)
# TRANSFERRING ||############################............||(648/929 MB:  69.72 %)
# TRANSFERRING ||############################............||(648/929 MB:  69.78 %)
# TRANSFERRING ||############################............||(649/929 MB:  69.89 %)
# TRANSFERRING ||#############################...........||(651/929 MB:  70.06 %)
# TRANSFERRING ||#############################...........||(652/929 MB:  70.18 %)
# TRANSFERRING ||#############################...........||(652/929 MB:  70.22 %)
# TRANSFERRING ||#############################...........||(655/929 MB:  70.48 %)
# TRANSFERRING ||#############################...........||(657/929 MB:  70.70 %)
# TRANSFERRING ||#############################...........||(657/929 MB:  70.72 %)
# TRANSFERRING ||#############################...........||(657/929 MB:  70.74 %)
# TRANSFERRING ||#############################...........||(657/929 MB:  70.75 %)
# TRANSFERRING ||#############################...........||(658/929 MB:  70.77 %)
# TRANSFERRING ||#############################...........||(658/929 MB:  70.78 %)
# TRANSFERRING ||#############################...........||(658/929 MB:  70.80 %)
# TRANSFERRING ||#############################...........||(658/929 MB:  70.82 %)
# TRANSFERRING ||#############################...........||(658/929 MB:  70.83 %)
# TRANSFERRING ||#############################...........||(658/929 MB:  70.85 %)
# TRANSFERRING ||#############################...........||(658/929 MB:  70.87 %)
# TRANSFERRING ||#############################...........||(659/929 MB:  70.88 %)
# TRANSFERRING ||#############################...........||(659/929 MB:  70.90 %)
# TRANSFERRING ||#############################...........||(659/929 MB:  70.92 %)
# TRANSFERRING ||#############################...........||(659/929 MB:  70.94 %)
# TRANSFERRING ||#############################...........||(659/929 MB:  70.96 %)
# TRANSFERRING ||#############################...........||(659/929 MB:  70.97 %)
# TRANSFERRING ||#############################...........||(660/929 MB:  70.98 %)
# TRANSFERRING ||#############################...........||(663/929 MB:  71.31 %)
# TRANSFERRING ||#############################...........||(667/929 MB:  71.77 %)
# TRANSFERRING ||#############################...........||(668/929 MB:  71.94 %)
# TRANSFERRING ||#############################...........||(669/929 MB:  71.96 %)
# TRANSFERRING ||#############################...........||(669/929 MB:  71.97 %)
# TRANSFERRING ||#############################...........||(669/929 MB:  72.00 %)
# TRANSFERRING ||#############################...........||(669/929 MB:  72.03 %)
# TRANSFERRING ||#############################...........||(670/929 MB:  72.09 %)
# TRANSFERRING ||#############################...........||(672/929 MB:  72.31 %)
# TRANSFERRING ||##############################..........||(679/929 MB:  73.03 %)
# TRANSFERRING ||##############################..........||(682/929 MB:  73.45 %)
# TRANSFERRING ||##############################..........||(683/929 MB:  73.48 %)
# TRANSFERRING ||##############################..........||(686/929 MB:  73.81 %)
# TRANSFERRING ||##############################..........||(687/929 MB:  73.96 %)
# TRANSFERRING ||##############################..........||(687/929 MB:  73.97 %)
# TRANSFERRING ||##############################..........||(687/929 MB:  73.98 %)
# TRANSFERRING ||##############################..........||(687/929 MB:  73.99 %)
# TRANSFERRING ||##############################..........||(688/929 MB:  74.00 %)
# TRANSFERRING ||##############################..........||(688/929 MB:  74.01 %)
# TRANSFERRING ||##############################..........||(688/929 MB:  74.02 %)
# TRANSFERRING ||##############################..........||(688/929 MB:  74.03 %)
# TRANSFERRING ||##############################..........||(688/929 MB:  74.04 %)
# TRANSFERRING ||##############################..........||(688/929 MB:  74.05 %)
# TRANSFERRING ||##############################..........||(688/929 MB:  74.06 %)
# TRANSFERRING ||##############################..........||(688/929 MB:  74.07 %)
# TRANSFERRING ||##############################..........||(688/929 MB:  74.08 %)
# TRANSFERRING ||##############################..........||(688/929 MB:  74.10 %)
# TRANSFERRING ||##############################..........||(689/929 MB:  74.10 %)
# TRANSFERRING ||##############################..........||(689/929 MB:  74.11 %)
# TRANSFERRING ||##############################..........||(689/929 MB:  74.13 %)
# TRANSFERRING ||##############################..........||(689/929 MB:  74.14 %)
# TRANSFERRING ||##############################..........||(689/929 MB:  74.15 %)
# TRANSFERRING ||##############################..........||(689/929 MB:  74.17 %)
# TRANSFERRING ||##############################..........||(689/929 MB:  74.18 %)
# TRANSFERRING ||##############################..........||(689/929 MB:  74.19 %)
# TRANSFERRING ||##############################..........||(689/929 MB:  74.21 %)
# TRANSFERRING ||##############################..........||(690/929 MB:  74.22 %)
# TRANSFERRING ||##############################..........||(690/929 MB:  74.23 %)
# TRANSFERRING ||##############################..........||(690/929 MB:  74.24 %)
# TRANSFERRING ||##############################..........||(690/929 MB:  74.26 %)
# TRANSFERRING ||##############################..........||(690/929 MB:  74.28 %)
# TRANSFERRING ||##############################..........||(690/929 MB:  74.28 %)
# TRANSFERRING ||##############################..........||(690/929 MB:  74.28 %)
# TRANSFERRING ||##############################..........||(690/929 MB:  74.30 %)
# TRANSFERRING ||##############################..........||(690/929 MB:  74.31 %)
# TRANSFERRING ||##############################..........||(691/929 MB:  74.33 %)
# TRANSFERRING ||##############################..........||(691/929 MB:  74.35 %)
# TRANSFERRING ||##############################..........||(691/929 MB:  74.36 %)
# TRANSFERRING ||##############################..........||(691/929 MB:  74.38 %)
# TRANSFERRING ||##############################..........||(691/929 MB:  74.40 %)
# TRANSFERRING ||##############################..........||(691/929 MB:  74.42 %)
# TRANSFERRING ||##############################..........||(692/929 MB:  74.44 %)
# TRANSFERRING ||##############################..........||(692/929 MB:  74.47 %)
# TRANSFERRING ||##############################..........||(692/929 MB:  74.51 %)
# TRANSFERRING ||##############################..........||(693/929 MB:  74.56 %)
# TRANSFERRING ||##############################..........||(693/929 MB:  74.63 %)
# TRANSFERRING ||##############################..........||(694/929 MB:  74.74 %)
# TRANSFERRING ||##############################..........||(696/929 MB:  74.94 %)
# ...
# TRANSFERRING ||######################################..||(917/987 MB:  92.88 %)
# TRANSFERRING ||######################################..||(917/987 MB:  92.92 %)
# TRANSFERRING ||######################################..||(917/987 MB:  92.96 %)
# TRANSFERRING ||######################################..||(918/987 MB:  93.00 %)
# TRANSFERRING ||######################################..||(918/987 MB:  93.04 %)
# TRANSFERRING ||######################################..||(919/987 MB:  93.09 %)
# TRANSFERRING ||######################################..||(919/987 MB:  93.13 %)
# TRANSFERRING ||######################################..||(920/987 MB:  93.18 %)
# TRANSFERRING ||######################################..||(920/987 MB:  93.22 %)
# TRANSFERRING ||######################################..||(920/987 MB:  93.26 %)
# TRANSFERRING ||######################################..||(921/987 MB:  93.30 %)
# TRANSFERRING ||######################################..||(921/987 MB:  93.34 %)
# TRANSFERRING ||######################################..||(922/987 MB:  93.38 %)
# TRANSFERRING ||######################################..||(922/987 MB:  93.41 %)
# TRANSFERRING ||######################################..||(922/987 MB:  93.45 %)
# TRANSFERRING ||######################################..||(923/987 MB:  93.50 %)
# TRANSFERRING ||######################################..||(923/987 MB:  93.55 %)
# TRANSFERRING ||######################################..||(924/987 MB:  93.60 %)
# TRANSFERRING ||######################################..||(924/987 MB:  93.65 %)
# TRANSFERRING ||######################################..||(925/987 MB:  93.70 %)
# TRANSFERRING ||######################################..||(925/987 MB:  93.75 %)
# TRANSFERRING ||######################################..||(926/987 MB:  93.80 %)
# TRANSFERRING ||######################################..||(926/987 MB:  93.86 %)
# TRANSFERRING ||######################################..||(927/987 MB:  93.91 %)
# TRANSFERRING ||######################################..||(927/987 MB:  93.96 %)
# TRANSFERRING ||######################################..||(928/987 MB:  94.00 %)
# TRANSFERRING ||######################################..||(928/987 MB:  94.06 %)
# TRANSFERRING ||######################################..||(929/987 MB:  94.12 %)
# TRANSFERRING ||######################################..||(929/987 MB:  94.17 %)
# TRANSFERRING ||######################################..||(930/987 MB:  94.22 %)
# TRANSFERRING ||######################################..||(930/987 MB:  94.27 %)
# TRANSFERRING ||######################################..||(931/987 MB:  94.31 %)
# TRANSFERRING ||######################################..||(931/987 MB:  94.34 %)
# TRANSFERRING ||######################################..||(932/987 MB:  94.38 %)
# TRANSFERRING ||######################################..||(932/987 MB:  94.42 %)
# TRANSFERRING ||######################################..||(932/987 MB:  94.47 %)
# TRANSFERRING ||######################################..||(933/987 MB:  94.51 %)
# TRANSFERRING ||######################################..||(933/987 MB:  94.56 %)
# TRANSFERRING ||######################################..||(934/987 MB:  94.60 %)
# TRANSFERRING ||######################################..||(934/987 MB:  94.65 %)
# TRANSFERRING ||######################################..||(935/987 MB:  94.69 %)
# TRANSFERRING ||######################################..||(935/987 MB:  94.74 %)
# TRANSFERRING ||######################################..||(936/987 MB:  94.79 %)
# TRANSFERRING ||######################################..||(936/987 MB:  94.84 %)
# TRANSFERRING ||######################################..||(936/987 MB:  94.88 %)
# TRANSFERRING ||######################################..||(937/987 MB:  94.93 %)
# TRANSFERRING ||######################################..||(937/987 MB:  94.97 %)
# TRANSFERRING ||#######################################.||(938/987 MB:  95.02 %)
# TRANSFERRING ||#######################################.||(938/987 MB:  95.06 %)
# TRANSFERRING ||#######################################.||(939/987 MB:  95.09 %)
# TRANSFERRING ||#######################################.||(939/987 MB:  95.12 %)
# TRANSFERRING ||#######################################.||(939/987 MB:  95.15 %)
# TRANSFERRING ||#######################################.||(940/987 MB:  95.19 %)
# TRANSFERRING ||#######################################.||(940/987 MB:  95.24 %)
# TRANSFERRING ||#######################################.||(940/987 MB:  95.28 %)
# TRANSFERRING ||#######################################.||(941/987 MB:  95.32 %)
# TRANSFERRING ||#######################################.||(941/987 MB:  95.36 %)
# TRANSFERRING ||#######################################.||(942/987 MB:  95.40 %)
# TRANSFERRING ||#######################################.||(942/987 MB:  95.45 %)
# TRANSFERRING ||#######################################.||(942/987 MB:  95.49 %)
# TRANSFERRING ||#######################################.||(943/987 MB:  95.53 %)
# TRANSFERRING ||#######################################.||(943/987 MB:  95.57 %)
# TRANSFERRING ||######################################..||(936/987 MB:  94.80 %)
# TRANSFERRING ||#######################################.||(944/987 MB:  95.65 %)
# TRANSFERRING ||#######################################.||(944/987 MB:  95.69 %)
# TRANSFERRING ||#######################################.||(945/987 MB:  95.73 %)
# TRANSFERRING ||#######################################.||(945/987 MB:  95.78 %)
# TRANSFERRING ||#######################################.||(946/987 MB:  95.82 %)
# TRANSFERRING ||#######################################.||(946/987 MB:  95.87 %)
# TRANSFERRING ||#######################################.||(947/987 MB:  95.91 %)
# TRANSFERRING ||#######################################.||(947/987 MB:  95.96 %)
# TRANSFERRING ||#######################################.||(947/987 MB:  95.99 %)
# TRANSFERRING ||#######################################.||(948/987 MB:  96.03 %)
# TRANSFERRING ||#######################################.||(948/987 MB:  96.06 %)
# TRANSFERRING ||#######################################.||(949/987 MB:  96.11 %)
# TRANSFERRING ||#######################################.||(949/987 MB:  96.15 %)
# TRANSFERRING ||#######################################.||(949/987 MB:  96.19 %)
# TRANSFERRING ||#######################################.||(950/987 MB:  96.24 %)
# TRANSFERRING ||#######################################.||(950/987 MB:  96.28 %)
# TRANSFERRING ||#######################################.||(951/987 MB:  96.33 %)
# TRANSFERRING ||#######################################.||(951/987 MB:  96.37 %)
# TRANSFERRING ||#######################################.||(952/987 MB:  96.42 %)
# TRANSFERRING ||#######################################.||(952/987 MB:  96.47 %)
# TRANSFERRING ||#######################################.||(953/987 MB:  96.52 %)
# TRANSFERRING ||#######################################.||(953/987 MB:  96.56 %)
# TRANSFERRING ||#######################################.||(954/987 MB:  96.61 %)
# TRANSFERRING ||#######################################.||(954/987 MB:  96.66 %)
# TRANSFERRING ||#######################################.||(954/987 MB:  96.70 %)
# TRANSFERRING ||#######################################.||(955/987 MB:  96.75 %)
# TRANSFERRING ||#######################################.||(955/987 MB:  96.79 %)
# TRANSFERRING ||#######################################.||(956/987 MB:  96.83 %)
# TRANSFERRING ||#######################################.||(956/987 MB:  96.88 %)
# TRANSFERRING ||#######################################.||(957/987 MB:  96.92 %)
# TRANSFERRING ||#######################################.||(957/987 MB:  96.97 %)
# TRANSFERRING ||#######################################.||(958/987 MB:  97.02 %)
# TRANSFERRING ||#######################################.||(958/987 MB:  97.07 %)
# TRANSFERRING ||#######################################.||(959/987 MB:  97.11 %)
# TRANSFERRING ||#######################################.||(959/987 MB:  97.16 %)
# TRANSFERRING ||#######################################.||(959/987 MB:  97.21 %)
# TRANSFERRING ||#######################################.||(960/987 MB:  97.25 %)
# TRANSFERRING ||#######################################.||(960/987 MB:  97.28 %)
# TRANSFERRING ||#######################################.||(961/987 MB:  97.31 %)
# TRANSFERRING ||#######################################.||(961/987 MB:  97.35 %)
# TRANSFERRING ||#######################################.||(961/987 MB:  97.39 %)
# TRANSFERRING ||#######################################.||(962/987 MB:  97.43 %)
# TRANSFERRING ||#######################################.||(962/987 MB:  97.47 %)
# TRANSFERRING ||########################################||(962/987 MB:  97.50 %)
# TRANSFERRING ||########################################||(963/987 MB:  97.52 %)
# TRANSFERRING ||########################################||(963/987 MB:  97.54 %)
# TRANSFERRING ||########################################||(963/987 MB:  97.55 %)
# TRANSFERRING ||########################################||(963/987 MB:  97.57 %)
# TRANSFERRING ||########################################||(963/987 MB:  97.58 %)
# TRANSFERRING ||########################################||(963/987 MB:  97.59 %)
# TRANSFERRING ||########################################||(964/987 MB:  97.62 %)
# TRANSFERRING ||########################################||(964/987 MB:  97.67 %)
# TRANSFERRING ||########################################||(964/987 MB:  97.70 %)
# TRANSFERRING ||########################################||(965/987 MB:  97.74 %)
# TRANSFERRING ||########################################||(965/987 MB:  97.78 %)
# TRANSFERRING ||########################################||(965/987 MB:  97.82 %)
# TRANSFERRING ||########################################||(966/987 MB:  97.86 %)
# TRANSFERRING ||########################################||(966/987 MB:  97.90 %)
# TRANSFERRING ||########################################||(967/987 MB:  97.94 %)
# TRANSFERRING ||########################################||(967/987 MB:  97.97 %)
# TRANSFERRING ||########################################||(967/987 MB:  98.00 %)
# TRANSFERRING ||########################################||(968/987 MB:  98.04 %)
# TRANSFERRING ||########################################||(968/987 MB:  98.08 %)
# TRANSFERRING ||########################################||(969/987 MB:  98.13 %)
# TRANSFERRING ||########################################||(969/987 MB:  98.18 %)
# TRANSFERRING ||########################################||(970/987 MB:  98.23 %)
# TRANSFERRING ||########################################||(970/987 MB:  98.27 %)
# TRANSFERRING ||########################################||(970/987 MB:  98.32 %)
# TRANSFERRING ||########################################||(971/987 MB:  98.37 %)
# TRANSFERRING ||########################################||(971/987 MB:  98.42 %)
# TRANSFERRING ||########################################||(972/987 MB:  98.45 %)
# TRANSFERRING ||########################################||(972/987 MB:  98.49 %)
# TRANSFERRING ||########################################||(973/987 MB:  98.53 %)
# TRANSFERRING ||########################################||(973/987 MB:  98.58 %)
# TRANSFERRING ||########################################||(973/987 MB:  98.61 %)
# TRANSFERRING ||########################################||(974/987 MB:  98.64 %)
# TRANSFERRING ||########################################||(974/987 MB:  98.67 %)
# TRANSFERRING ||########################################||(974/987 MB:  98.69 %)
# TRANSFERRING ||########################################||(974/987 MB:  98.72 %)
# TRANSFERRING ||########################################||(975/987 MB:  98.75 %)
# TRANSFERRING ||########################################||(975/987 MB:  98.79 %)
# TRANSFERRING ||########################################||(975/987 MB:  98.82 %)
# TRANSFERRING ||########################################||(976/987 MB:  98.87 %)
# TRANSFERRING ||########################################||(976/987 MB:  98.91 %)
# TRANSFERRING ||########################################||(977/987 MB:  98.96 %)
# TRANSFERRING ||########################################||(977/987 MB:  99.00 %)
# TRANSFERRING ||########################################||(978/987 MB:  99.05 %)
# TRANSFERRING ||########################################||(978/987 MB:  99.09 %)
# TRANSFERRING ||########################################||(978/987 MB:  99.13 %)
# TRANSFERRING ||########################################||(979/987 MB:  99.17 %)
# TRANSFERRING ||########################################||(979/987 MB:  99.22 %)
# TRANSFERRING ||########################################||(980/987 MB:  99.24 %)
# TRANSFERRING ||########################################||(980/987 MB:  99.26 %)
# TRANSFERRING ||########################################||(980/987 MB:  99.28 %)
# TRANSFERRING ||########################################||(980/987 MB:  99.30 %)
# TRANSFERRING ||########################################||(980/987 MB:  99.32 %)
# TRANSFERRING ||########################################||(980/987 MB:  99.33 %)
# TRANSFERRING ||########################################||(980/987 MB:  99.34 %)
# TRANSFERRING ||########################################||(981/987 MB:  99.35 %)
# TRANSFERRING ||########################################||(981/987 MB:  99.36 %)
# TRANSFERRING ||########################################||(981/987 MB:  99.40 %)
# TRANSFERRING ||########################################||(981/987 MB:  99.43 %)
# TRANSFERRING ||########################################||(982/987 MB:  99.47 %)
# TRANSFERRING ||########################################||(982/987 MB:  99.50 %)
# TRANSFERRING ||########################################||(982/987 MB:  99.53 %)
# TRANSFERRING ||########################################||(983/987 MB:  99.56 %)
# TRANSFERRING ||########################################||(983/987 MB:  99.58 %)
# TRANSFERRING ||########################################||(983/987 MB:  99.60 %)
# TRANSFERRING ||########################################||(983/987 MB:  99.62 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.65 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.68 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.69 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.71 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.73 %)
# TRANSFERRING ||########################################||(984/987 MB:  99.74 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.75 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.76 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.77 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.78 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.79 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.81 %)
# TRANSFERRING ||########################################||(985/987 MB:  99.83 %)
# TRANSFERRING ||########################################||(986/987 MB:  99.85 %)
# TRANSFERRING ||########################################||(986/987 MB:  99.87 %)
# TRANSFERRING ||########################################||(986/987 MB:  99.89 %)
# TRANSFERRING ||########################################||(986/987 MB:  99.91 %)
# TRANSFERRING ||########################################||(986/987 MB:  99.93 %)
# TRANSFERRING ||########################################||(987/987 MB:  99.95 %)
# TRANSFERRING ||########################################||(987/987 MB:  99.97 %)
# TRANSFERRING ||########################################||(987/987 MB:  99.98 %)
# TRANSFERRING ||########################################||(987/987 MB: 100.00 %)
# TRANSFERRING ||########################################||(987/987 MB: 100.00 %)
# Download finished: /content/kcg-ml/./downloads/pixel-art-pinterest-030.zip
# TRANSFERRING ||########################################||(987/987 MB: 100.00 %)

# %% [markdown]
# # Preprocess the Dataset images (Stage 1)
#
# Process a tagged dataset and computes the images metadata along with its CLIP embeddings and writes the result into a JSON file in specified output folder. In addition, the SQLite database named `dataset_cache.sqlite` with table named `dataset_cache` containing file name, hash and file path for dataset images will be created in the `./output` folder.

# %% [markdown]
# ### Install Requirements

# %%
# %%capture
# %pip install ascii_graph open_clip_torch patool fire

# %% [markdown]
# ### Extract Downloaded ZIP-Archived Data (Optional)
# This step is optional. If this step is not performed, Stage 1 will perform the extraction

# %%
from zipfile import ZipFile

# Specify location of downloaded data (zip file)
downloaded_data_zip = "/content/kcg-ml/downloads/pixel-art-tagged-v3.zip"
# Location to extract the zip file to
dataset_path = f'./datasets/{os.path.splitext(os.path.split(downloaded_data_zip)[-1])[0]}'

with ZipFile(downloaded_data_zip) as zip_object:
    zip_object.extractall(dataset_path)

# %% [markdown]
# ### Set Required Variables by the Utility
#
# Initialize the required parameters needed by the dataset preprocessor utility and they are described as follows:
#
# * `input_folder` _[str]_ -  path to the directory containing sub-folders of each tag.
# * `output_folder` _[str]_ - path to the directory where to save the files into it.
# * `clip_model` _[str]_ - CLIP model to be used
# * `pretrained` _[str]_ - the pre-trained model to be used for CLIP
# * `batch_size` _[int]_ -  number of images to process at a time
# * `num_threads` _[int]_ - the number to be used in this process
# * `device` _[str]_ -  the device to be used in computing the CLIP embeddings, if `None` is provided then `cuda` will be used if available

# %%
# Specify the path to the dataset in dataset_path variable
# dataset_path = '/content/kcg-ml/downloads/pixel-art-tagged-v3.zip'
dataset_path = './datasets/testdata.zip'
output_folder = './output'
tagged_dataset = True
clip_model = 'ViT-L-14'
pretrained = 'laion2b_s32b_b82k'
batch_size = 32
num_threads = 4
device = None

# %% [markdown]
# ### Run the Preprocessor

# %%
ImageDatasetProcessor.process_dataset(
    dataset_path, 
    output_folder,
    tagged_dataset, 
    clip_model, 
    pretrained,
    batch_size, 
    num_threads, 
    device
)
# Out:
# Downloading:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# patool: Extracting ./datasets/testdata.zip ...
# patool: running /usr/bin/7z x -o./datasets/testdata-decompressed-tmp -- ./datasets/testdata.zip
# patool: ... ./datasets/testdata.zip extracted to `./datasets/testdata-decompressed-tmp'.
# is archive dataset
# dataset folder path  = ./datasets/testdata-decompressed-tmp/testdata
# Processing...
# 100%|██████████| 1/1 [00:07<00:00,  7.99s/it]
# [INFO] Writing to database table in ./output/dataset_cache.sqlite
# [INFO] Finished.

# %% [markdown]
# # Train the Classifiers (Stage 2)
# Given a `metadata` json file containing embeddings for images and `tag-to-image-hash` json file containing images' hash with tags, the script start to make for every tag two binary classification models and save it in output folder.

# %% [markdown]
# ### Train Script Variables
#
# * `metadata_json` _[string]_ - _[required]_ - The path to the metadata json file.
# * `tag_to_hash_json` _[string]_ - _[required]_ - The path to tag-to-hash json file.
# * `output` _[string]_ - _[optional]_ - The path to the output directory.
# * `test_per` _[float]_ - _[optional]_ - The percentage of the test images from the dataset, default = 0.1

# %%
# Run from ./image-tagging-tools directory
metadata_json = './output/input-metadata.json' 
tag_to_hash_json = './output/input-tag-to-image-hash-list.json'
output_dir = './output'
test_per = 0.1

# %% [markdown]
# ### Run the Training Script

# %%
train_main(
    metadata_json = metadata_json,
    tag_to_hash_json = tag_to_hash_json,
    output_dir = output_dir,
    test_per = test_per
)
# Out:
# Initialize new classifier model for type: ovr-logistic-regression and tag: not-pixel-art-real-photo
# Initialize new classifier model for type: ovr-svm and tag: not-pixel-art-real-photo
# Initialize new classifier model for type: torch-logistic-regression and tag: not-pixel-art-real-photo
# Initialize new classifier model for type: ovr-logistic-regression and tag: not-pixel-art
# Initialize new classifier model for type: ovr-svm and tag: not-pixel-art
# Initialize new classifier model for type: torch-logistic-regression and tag: not-pixel-art
# [INFO] Finished.

# %% [markdown]
# ### Get List of Type and Tag Pairs from All Models'''

# %%
# Creating model object
model_api = ModelApi()
type_tag_pair = model_api.get_type_tag_pair() 
print (type_tag_pair)
# Out:
# [('ovr-logistic-regression', 'not-pixel-art-real-photo'), ('torch-logistic-regression', 'not-pixel-art'), ('ovr-logistic-regression', 'not-pixel-art'), ('ovr-svm', 'not-pixel-art-real-photo'), ('torch-logistic-regression', 'not-pixel-art-real-photo'), ('ovr-svm', 'not-pixel-art')]

# %% [markdown]
# # Classify Data (Stage 3)
# Running the classifier. The script will loop over every image and make the classification for it using every binary classification model. Running the classifier can be performed from command line interface (CLI) or within Python runtime as shown in the following examples.

# %% [markdown]
# ## Running the classifier from Command Line Interface (CLI Version)

# %%
# !touch ./__init__.py

# %%
# !python3 ./image_classifier_pipeline/classify/classify.py --directory=$dataset_path --metadata_json=./output/input-metadata.json --output=./output --output_bins=10 --model_type=ovr-logistic-regression --tag=not-pixel-art
# Out:
# [INFO] Output folder ./output/tagging_output_2023_4_11_21_3_36
#   0% 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s][INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
#
# 1it [00:09,  9.37s/it] Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
#
# 2it [00:09,  3.92s/it] Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
#
# 4it [00:09,  1.51s/it] Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
#
# 6it [00:09,  1.20it/s] Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
#
# 8it [00:09,  1.88it/s] Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
#
# 10it [00:10,  2.72it/s] Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
#
# 12it [00:10,  3.70it/s] Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
#
# 14it [00:10,  5.00it/s] Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
#
# 16it [00:10,  6.07it/s] Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
#
# 19it [00:10,  8.36it/s] Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
#
# 21it [00:10,  9.11it/s] Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
#
# 24it [00:11,  2.18it/s]
# 100% 1/1 [00:11<00:00, 11.02s/it]
# ./output//zip_score_cache.sqlite
# [INFO] Writing to database table in ./output//zip_score_cache.sqlite
# [INFO] Finished.

# %% [markdown]
# ### CLI Arguments
#
# * `directory` _[string]_ - _[required]_ - The path to the images' folder or images' .zip file.
# * `metadata_json` _[string]_ - _[required]_ - The path to the metadata json file for CLIP embeddings.
# * `output` _[string]_ - _[optional]_ - The path to the output directory for the inference results.
# * `model_type` _[string]_ - _[required]_ - The type of the model (example: `ovr-logistic-regression`, `ovr-svm`, `torch-logistic-regression`).
# * `tag` _[string]_ - _[required]_ - Tag string (example: `pos-character`, `pos-environmental-space`, etc).
# * `output_bins` _[int]_ - _[optional]_ -  The number of bins of the results for each model.
#
# If the `--output` argument is not specified, the classification / inference result will be placed at `./output/tagging_output` folder. Time stamp will be appended to folder name (for example: `./output/tagging_output_2023_1_21_0_56`).
# In addition, the SQLite database named `score_cache.sqlite` with table named `score_cache` containing file name, file path, file hash, model name, model type, model train date, tag string and tag score for given images will be created in the `./output` folder. For archived (ZIP) files the SQLite database named `zip_score_cache.sqlite` with table named `zip_score_cache` containing file name, file path, archive path, type of file, hash, model type, tag name and tag score for given images will be created in the `output` folder.

# %% [markdown]
# ## Running the Classifier (from Python Runtime)
#
# ### Variables for Classifier
# * `data_path` _[string]_ - _[required]_ - The path to the images data folder or single image file'.
# * `json_file_path` _[string]_ - _[required]_ - The path to the metadata json file for CLIP embeddings.
# * `output_dir` _[string]_ - _[optional]_ - The path to the output directory for the inference results.
# * `model_type` _[string]_ - _[required]_ - The type of the model (example: `ovr-logistic-regression`, `ovr-svm`, `torch-logistic-regression`)
# * `tag` _[string]_ - _[required]_ - Tag string (example: `pos-character`, `pos-environmental-space`, etc).
# * `bins_number` _[int]_ - _[optional]_ -  The number of bins of the results for each model.

# %% [markdown]
# ### Classify Images Data in Folder with Single Model

# %%
# Specify path to folder containing images data in data_path variable
# data_path = '../path/to/image/data/folder/'
# Or test with images in dataset
data_path    = dataset_path
output_dir     = './output/'
json_file_path = './output/input-metadata.json'
bins_number    = 10
# Specify the type of model
model_type = 'ovr-logistic-regression'
# Specify the tag string
tag = 'not-pixel-art'

# %%
classify_main(
        folder_path    = data_path, 
        output_dir     = output_dir, 
        json_file_path = json_file_path, 
        bins_number = bins_number,
        model_type = model_type, 
        tag = tag
        )
# Out:
# [INFO] Output folder ./output//tagging_output_2023_4_11_21_5_7
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 1it [00:00,  8.08it/s]
# [INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
# 6it [00:00, 28.82it/s]
# 9it [00:00, 27.30it/s]
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
# 12it [00:00, 17.19it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
# 15it [00:00, 15.65it/s]
# 19it [00:01, 17.93it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
# 24it [00:01, 20.52it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# ./output///zip_score_cache.sqlite
# [INFO] Writing to database table in ./output///zip_score_cache.sqlite
# [INFO] Finished.

# %% [markdown]
# ### Classify Single Image with Single Model

# %%
# Specify path to single image to be classified in data_path
#data_path    = '../path/to/image/file'
# Or test with sample image from dataset
data_path    = './datasets/testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg'
output_dir     = './output/classification_single_image_single_model'
json_file_path = './output/input-metadata.json'
bins_number    = 10
# Specify the type of model
model_type = 'torch-logistic-regression'
# Specify the tag string
tag = 'not-pixel-art'

# %%
classify_main(
        folder_path    = data_path, 
        output_dir     = output_dir, 
        json_file_path = json_file_path, 
        bins_number = bins_number,
        model_type = model_type, 
        tag = tag 
        )
# Out:
# [INFO] Output folder ./output/classification_single_image_single_model/tagging_output_2023_4_11_21_5_28
# 100%|██████████| 1/1 [00:00<00:00, 10.62it/s]
# [INFO] Writing to database table in ./output/classification_single_image_single_model//score_cache.sqlite
# [INFO] Finished.

# %% [markdown]
# ### Classify Images Data in Folder with All Models

# %%
# Specify path to folder containing images data in data_path variable
# data_path = '../path/to/image/data/folder/'
# Or test with images in dataset
data_path    = dataset_path
output_dir     = './output/'
json_file_path = './output/input-metadata.json'
bins_number    = 10

# %%
# Creating model object
model_api = ModelApi()

# Get list of model type and tag pair
type_tag_pair = model_api.get_type_tag_pair() 

for model_type, tag in type_tag_pair:
        classify_main(
                folder_path    = data_path, 
                output_dir     = output_dir, 
                json_file_path = json_file_path, 
                bins_number = bins_number,
                model_type = model_type, 
                tag = tag 
                )
# Out:
# [INFO] Output folder ./output//tagging_output_2023_4_11_21_5_42
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 1it [00:00,  8.60it/s]
# [INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
# 6it [00:00, 30.61it/s]
# 10it [00:00, 30.39it/s]
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
# 14it [00:00, 17.21it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
# 17it [00:00, 18.50it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
# 24it [00:01, 21.82it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# ./output///zip_score_cache.sqlite
# [INFO] Writing to database table in ./output///zip_score_cache.sqlite
# [INFO] Finished.
# [INFO] Output folder ./output//tagging_output_2023_4_11_21_5_50
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 2it [00:00, 19.54it/s]
# [INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
# 8it [00:00, 41.40it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
# 13it [00:00, 24.22it/s]
# 17it [00:00, 27.68it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
# 24it [00:00, 30.49it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# ./output///zip_score_cache.sqlite
# [INFO] Writing to database table in ./output///zip_score_cache.sqlite
# [INFO] Finished.
# [INFO] Output folder ./output//tagging_output_2023_4_11_21_5_56
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 2it [00:00, 15.77it/s]
# [INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
# 7it [00:00, 29.00it/s]
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
# 11it [00:00, 17.23it/s]
# 14it [00:00, 18.20it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
# 17it [00:00, 18.35it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
# 24it [00:01, 20.65it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# ./output///zip_score_cache.sqlite
# [INFO] Writing to database table in ./output///zip_score_cache.sqlite
# [INFO] Finished.
# [INFO] Output folder ./output//tagging_output_2023_4_11_21_6_2
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 2it [00:00, 19.76it/s]
# [INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
# 9it [00:00, 42.87it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
# 14it [00:00, 26.20it/s]
# 18it [00:00, 29.11it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
# 24it [00:00, 31.07it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.27it/s]
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# ./output///zip_score_cache.sqlite
# [INFO] Writing to database table in ./output///zip_score_cache.sqlite
# [INFO] Finished.
# [INFO] Output folder ./output//tagging_output_2023_4_11_21_6_10
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 3it [00:00, 26.90it/s]
# [INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
# 8it [00:00, 39.70it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
# 13it [00:00, 23.48it/s]
# 18it [00:00, 29.62it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
# 24it [00:00, 30.79it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# ./output///zip_score_cache.sqlite
# [INFO] Writing to database table in ./output///zip_score_cache.sqlite
# [INFO] Finished.
# [INFO] Output folder ./output//tagging_output_2023_4_11_21_6_16
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 1it [00:00,  9.15it/s]
# [INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
# 6it [00:00, 31.40it/s]
# 10it [00:00, 30.38it/s]
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
# 14it [00:00, 17.59it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
# 17it [00:00, 18.93it/s]
# 20it [00:00, 19.31it/s]
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
# 24it [00:01, 22.98it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# ./output///zip_score_cache.sqlite
# [INFO] Writing to database table in ./output///zip_score_cache.sqlite
# [INFO] Finished.

# %% [markdown]
# ### Classification for 'other-validation' Folder (pre-computed CLIP embeddings)

# %%
# Specify path to dataset folder containing 'other-validation' folder in dataset_path variable
dataset_path = 'datasets/testdata'
other_validation_path = os.path.join(dataset_path,'other-validation')
output_dir     = './output/classification_other_validation'
json_file_path =  './output/input-metadata.json'
bins_number    = 10
# Specify the type of model
model_type = 'ovr-logistic-regression'
# Specify the tag string
tag = 'not-pixel-art'

# %%
classify_main(
        folder_path    = other_validation_path, 
        output_dir     = output_dir, 
        json_file_path = json_file_path, 
        bins_number    = bins_number, 
        model_type = model_type, 
        tag = tag 
        )
# Out:
# [INFO] Output folder ./output/classification_other_validation/tagging_output_2023_4_11_21_7_47
# 100%|██████████| 4/4 [00:00<00:00, 178.16it/s]
# [INFO] Writing to database table in ./output/classification_other_validation//score_cache.sqlite
# [INFO] Finished.

# %% [markdown]
# ### Get Score for Images Data in ZIP Archive with Single Model (Tag) and Run Function Based on Score

# %%
from classify_helper_functions import zip_gen, get_single_tag_score, get_clip, get_classifier_model

# Specify ZIP archive containing images data
folder_path    = './datasets/testdata.zip'
# Specify the type of model
model_type = 'ovr-logistic-regression'
# Specify the tag string
tag = 'not-pixel-art'
# Score threshold to run the function
th_score       = 0.2

# %%
def any_function_to_run(score):
    '''Function to run when certain prob_score is met'''
    print ('OK')

# %%
# import torch
# from PIL import Image

# image_file_name = "/content/kcg-ml/datasets/test_images/example1.jpg"
# img = Image.open(image_file_name)

# with torch.no_grad():

#   if image_file_name.lower().endswith('.gif'): 
#     img_obj = convert_gif_to_image(img)  
#   else:
#     img_obj = img

#   image = preprocess(img_obj).unsqueeze(0).to(device)
#   model = clip_model.to(device)
#   output = model.encode_image(image).cpu().detach().numpy()

# print(output)

# %%
clip_model , preprocess , device = get_clip(clip_model_type= 'ViT-L-14',pretrained= 'laion2b_s32b_b82k')
model = get_classifier_model(model_type = model_type, tag = tag)

# If model not found then return
if model != {}:
    # Loop through each zip file.
    for file in [folder_path]:
        # Generating images
        for img, img_file_name in zip_gen(file):
            # Calculate score
            score = get_single_tag_score(img, img_file_name, model, clip_model, preprocess, device)
            print (f'[INFO] Score: {score}')
            if th_score < score:
                any_function_to_run(score)
else:
    print ('[INFO]: Model not found. No classification performed.')

print("[INFO] Finished.")
# Out:
# [INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
# [INFO] Score: 0.9013001399782239
# OK
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
# [INFO] Score: 0.976080593306135
# OK
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
# [INFO] Score: 0.966614591197742
# OK
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
# [INFO] Score: 0.990198054228875
# OK
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
# [INFO] Score: 0.9472227229847028
# OK
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
# [INFO] Score: 0.9547476864619138
# OK
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
# [INFO] Score: 0.9852175113851677
# OK
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
# [INFO] Score: 0.9589658453014596
# OK
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
# [INFO] Score: 0.9968407329022093
# OK
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
# [INFO] Score: 0.9945988579839706
# OK
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
# [INFO] Score: 0.9907521111489024
# OK
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
# [INFO] Score: 0.9892067413585189
# OK
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
# [INFO] Score: 0.9940889050108179
# OK
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
# [INFO] Score: 0.994135003236189
# OK
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
# [INFO] Score: 0.988241634000759
# OK
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
# [INFO] Score: 0.7588482834108546
# OK
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
# [INFO] Score: 0.6903424326740999
# OK
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
# [INFO] Score: 0.01549230565217885
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
# [INFO] Score: 0.01698199019967006
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
# [INFO] Score: 0.019670324714305187
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
# [INFO] Score: 0.3199220302303354
# OK
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
# [INFO] Score: 0.4996706684599639
# OK
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
# [INFO] Score: 0.9791465096685799
# OK
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# [INFO] Score: 0.13955151839271385
# [INFO] Finished.

# %% [markdown]
# ## ZIP Archive: Reading Image Files, Compute CLIP and Send to Single Classifier (based on Type and Tag)

# %% [markdown]
# ### Import Required Functions

# %%
import sys
sys.path.insert(0, './image_classifier_pipeline/classify/')
import os
import datetime
import numpy as np
from classify import zip_gen as zip_image_iterator
from classify_helper_functions import file_to_hash_zip, load_json, get_clip, get_classifier_model, clip_image_features_zip, classify_image_prob, get_bins_array, find_bin, make_dir

# %% [markdown]
# ### Specify ZIP Archive Location, Model Type and Tag

# %%
# Specify ZIP archive containing images data
zip_file_path = './datasets/testdata.zip'
# Specify folder path to write classified images
output_dir = './output'
# Metadata json file location
json_file_path = './output/input-metadata.json'
# Specify the type of model
model_type = 'ovr-logistic-regression'
# Specify the tag string
tag = 'not-pixel-art'
# Number of classification score (probability) bins
n_bins = 10

# %% [markdown]
# ### Create Classifier and CLIP Model

# %%
# Get classifier model
model = get_classifier_model(model_type = model_type, tag = tag)
if model != {}:
    classifier = model['classifier']
    torch_model = 'torch' in model['model_type']
    # Get CLIP model, to calculate CLIP embeddings if it's not in .json metadata file.
    clip_model , preprocess , device = get_clip(clip_model_type= 'ViT-L-14',pretrained= 'laion2b_s32b_b82k')
    # Creating bins
    bins  = get_bins_array(n_bins)
else:
    print ('[INFO]: Model not found. Unable to perform classification')

# %% [markdown]
# ### Reading, Compute CLIP and Send to Single Classifier for Each File in ZIP Archive

# %%
# Loop through each zip file.
for file in [zip_file_path]:
    # Reading image files from ZIP archive
    for img, img_file_name in zip_image_iterator(file):

        # Hash
        hash_id = file_to_hash_zip(img, img_file_name)

        # Load the .json file.
        metadata_json_obj = load_json(json_file_path)

        # Clip features
        try : 
            # Check whether the hash_id exists in json file.
            image_features = np.array(metadata_json_obj[hash_id]["embeddings_vector"]).reshape(1,-1) 
        except:
            # hash_id does not exist in json file. Calculate image features.
            image_features = clip_image_features_zip(img, img_file_name, clip_model,preprocess,device) 

        # Calculate probability score
        score = classify_image_prob(image_features, classifier, torch_model=torch_model)
        print (score)

        # Get the bins 
        tag_bin, _= find_bin(bins , score) # get the bins 
        print (tag_bin)

        # Create folder for writing classified
        timestamp = datetime.datetime.now() 
        output_sub_dir = (f'tagging_output-{timestamp.year}_{timestamp.month}_{timestamp.day}_{timestamp.hour}_{timestamp.minute}_{timestamp.second}')
        tag_name_out_folder = make_dir([output_dir, output_sub_dir, f'{model_type}',f'{tag}',tag_bin])
    
        # Saving the image to file
        file_path = os.path.join(tag_name_out_folder, os.path.basename(img_file_name))
        img.save(file_path)
        print (f'[INFO] File {file_path} saved')

print("[INFO] Finished.")
# Out:
# [INFO] Working on ZIP archive: ./datasets/testdata.zip
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
# 0.9013004690538235
# 0.9
# [INFO] File ./output/tagging_output-2023_4_11_21_8_55/ovr-logistic-regression/not-pixel-art/0.9/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg saved
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
# 0.9760805726198688
# 1.0
# [INFO] File ./output/tagging_output-2023_4_11_21_8_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg saved
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
# 0.9666145736725641
# 1.0
# [INFO] File ./output/tagging_output-2023_4_11_21_8_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg saved
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
# 0.9901980382183092
# 1.0
# [INFO] File ./output/tagging_output-2023_4_11_21_8_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg saved
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
# 0.9472227797208866
# 0.9
# [INFO] File ./output/tagging_output-2023_4_11_21_8_55/ovr-logistic-regression/not-pixel-art/0.9/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg saved
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
# 0.9547476483016606
# 1.0
# [INFO] File ./output/tagging_output-2023_4_11_21_8_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg saved
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
# 0.9852175031490212
# 1.0
# [INFO] File ./output/tagging_output-2023_4_11_21_8_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg saved
#  Processing: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
# 0.9589658167876612
# 1.0
# [INFO] File ./output/tagging_output-2023_4_11_21_8_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg saved
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
# 0.9968407457004326
# 1.0
# [INFO] File ./output/tagging_output-2023_4_11_21_8_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg saved
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
# 0.9945988633443877
# 1.0
# [INFO] File ./output/tagging_output-2023_4_11_21_8_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg saved
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
# 0.9907521191798773
# 1.0
# [INFO] File ./output/tagging_output-2023_4_11_21_8_55/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg saved
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
# 0.9892067425818114
# 1.0
# [INFO] File ./output/tagging_output-2023_4_11_21_8_56/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png saved
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
# 0.9940888764170411
# 1.0
# [INFO] File ./output/tagging_output-2023_4_11_21_8_56/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg saved
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
# 0.9941349882342695
# 1.0
# [INFO] File ./output/tagging_output-2023_4_11_21_8_56/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png saved
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
# 0.9882417169855184
# 1.0
# [INFO] File ./output/tagging_output-2023_4_11_21_8_56/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg saved
#  Processing: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
# 0.7588481818453972
# 0.8
# [INFO] File ./output/tagging_output-2023_4_11_21_8_56/ovr-logistic-regression/not-pixel-art/0.8/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg saved
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
# 0.6903424465325365
# 0.7
# [INFO] File ./output/tagging_output-2023_4_11_21_8_56/ovr-logistic-regression/not-pixel-art/0.7/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg saved
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
# 0.01549230439447058
# 0.1
# [INFO] File ./output/tagging_output-2023_4_11_21_8_56/ovr-logistic-regression/not-pixel-art/0.1/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png saved
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
# 0.016982020264521114
# 0.1
# [INFO] File ./output/tagging_output-2023_4_11_21_8_56/ovr-logistic-regression/not-pixel-art/0.1/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png saved
#  Processing: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
# 0.019670290222368103
# 0.1
# [INFO] File ./output/tagging_output-2023_4_11_21_8_56/ovr-logistic-regression/not-pixel-art/0.1/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg saved
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
# 0.3199237252777928
# 0.3
# [INFO] File ./output/tagging_output-2023_4_11_21_8_56/ovr-logistic-regression/not-pixel-art/0.3/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg saved
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
# 0.4996709976279752
# 0.5
# [INFO] File ./output/tagging_output-2023_4_11_21_8_56/ovr-logistic-regression/not-pixel-art/0.5/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png saved
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
# 0.979146505862473
# 1.0
# [INFO] File ./output/tagging_output-2023_4_11_21_8_56/ovr-logistic-regression/not-pixel-art/1.0/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg saved
#  Processing: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# 0.13955132479435428
# 0.1
# [INFO] File ./output/tagging_output-2023_4_11_21_8_56/ovr-logistic-regression/not-pixel-art/0.1/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png saved
# [INFO] Finished.

# %% [markdown]
# # Using Classifier Model API

# %% [markdown]
# Model API contains function that accesses existing classifier model pickle files.

# %% [markdown]
# ### Create Classifier Model API Object

# %%
# Create model loader object with default model_path='./output/models/'
model_api = ModelApi()
# Or specify model_path explicitly'
# model_api = ModelApi(model_path='./output/models')

# %% [markdown]
# ### Get List of Model Types

# %%
model_types = model_api.get_model_types()
print (model_types)
# Out:
# ['ovr-logistic-regression', 'torch-logistic-regression', 'ovr-logistic-regression', 'ovr-svm', 'torch-logistic-regression', 'ovr-svm']

# %% [markdown]
# ### Get List of Tags Based on Model Type

# %%
model_type = (model_types[0])
tags = model_api.get_tags_by_model_type(model_type)
print (tags)
# Out:
# ['not-pixel-art-real-photo', 'not-pixel-art']

# %% [markdown]
# ### Get List of Type and Tag Pairs from All Models'''

# %%
type_tag_pair = model_api.get_type_tag_pair()
print (type_tag_pair)
'''
type_tag_pair is a list of tupple with the following structure
[(<model_type>,<tag>)]
'''
# Out:
# [('ovr-logistic-regression', 'not-pixel-art-real-photo'), ('torch-logistic-regression', 'not-pixel-art'), ('ovr-logistic-regression', 'not-pixel-art'), ('ovr-svm', 'not-pixel-art-real-photo'), ('torch-logistic-regression', 'not-pixel-art-real-photo'), ('ovr-svm', 'not-pixel-art')]
# '\ntype_tag_pair is a list of tupple with the following structure\n[(<model_type>,<tag>)]\n'

# %% [markdown]
# ### Get Model Based On Model Type and Tag

# %%
# Specify model type and tag
model_type, tag = type_tag_pair[0]
# Get the model dictionary
model = model_api.get_model_by_type_tag(model_type, tag)
print(model)
'''
Model is a dictionary with the following structure
{'classifier' : <model object>,
'model_type' : <model type string>,
'train_start_time' : <training start time datetime object>
'tag' : <tag string>
}
'''
# Out:
# {'classifier': LogisticRegression(multi_class='ovr', random_state=0), 'model_type': 'ovr-logistic-regression', 'train_start_time': datetime.datetime(2023, 4, 11, 20, 43, 27, 658810), 'tag': 'not-pixel-art-real-photo'}
# "\nModel is a dictionary with the following structure\n{'classifier' : <model object>,\n'model_type' : <model type string>,\n'train_start_time' : <training start time datetime object>\n'tag' : <tag string>\n}\n"

# %% [markdown]
# ### Get Models Dictionary for All Model Pickle Files

# %%
models_dict = model_api.get_models_dict()
print(models_dict)
'''
Example stucture of models_dict
{<model_name>: 
    {'classifier' : <model object>,
    'model_type' : <model type string>,
    'train_start_time' : <training start time datetime object>
    'tag' : <tag string>
    }
}
'''
# Out:
# {'model-ovr-logistic-regression-tag-not-pixel-art-real-photo': {'classifier': LogisticRegression(multi_class='ovr', random_state=0), 'model_type': 'ovr-logistic-regression', 'train_start_time': datetime.datetime(2023, 4, 11, 20, 43, 27, 658810), 'tag': 'not-pixel-art-real-photo'}, 'model-torch-logistic-regression-tag-not-pixel-art': {'classifier': LogisticRegressionPytorch(
#   (linear): Linear(in_features=768, out_features=1, bias=True)
# ), 'model_type': 'torch-logistic-regression', 'train_start_time': datetime.datetime(2023, 4, 11, 20, 43, 27, 658810), 'tag': 'not-pixel-art'}, 'model-ovr-logistic-regression-tag-not-pixel-art': {'classifier': LogisticRegression(multi_class='ovr', random_state=0), 'model_type': 'ovr-logistic-regression', 'train_start_time': datetime.datetime(2023, 4, 11, 20, 43, 27, 658810), 'tag': 'not-pixel-art'}, 'model-ovr-svm-tag-not-pixel-art-real-photo': {'classifier': SVC(decision_function_shape='ovo', probability=True), 'model_type': 'ovr-svm', 'train_start_time': datetime.datetime(2023, 4, 11, 20, 43, 27, 658810), 'tag': 'not-pixel-art-real-photo'}, 'model-torch-logistic-regression-tag-not-pixel-art-real-photo': {'classifier': LogisticRegressionPytorch(
#   (linear): Linear(in_features=768, out_features=1, bias=True)
# ), 'model_type': 'torch-logistic-regression', 'train_start_time': datetime.datetime(2023, 4, 11, 20, 43, 27, 658810), 'tag': 'not-pixel-art-real-photo'}, 'model-ovr-svm-tag-not-pixel-art': {'classifier': SVC(decision_function_shape='ovo', probability=True), 'model_type': 'ovr-svm', 'train_start_time': datetime.datetime(2023, 4, 11, 20, 43, 27, 658810), 'tag': 'not-pixel-art'}}
# "\nExample stucture of models_dict\n{<model_name>: \n    {'classifier' : <model object>,\n    'model_type' : <model type string>,\n    'train_start_time' : <training start time datetime object>\n    'tag' : <tag string>\n    }\n}\n"

# %% [markdown]
# # Other Examples

# %% [markdown]
# #### Get Files List from Folder or ZIP Archive

# %%
from zipfile import ZipFile

# Specify the path to the images data in the folder_path variable
folder_path    = './datasets/testdata.zip'

def fetch_file_paths(data_file):
    '''Yielding contained file paths in data_file'''

    if data_file.endswith('.zip'):

        # Selected data_dir is a zip archive
        with ZipFile(data_file) as archive:
            '''Getting archive details'''
            # Listing content
            entries = archive.infolist()

            for entry in entries:
                # Do for every content in the zip file
                if not entry.is_dir():
                    
                    with archive.open(entry) as file:

                        if entry.filename.lower().endswith(('.zip')):
                            # Another zip file found in the content.
                            with ZipFile(file) as sub_archive:
                                '''Getting archive details'''
                                sub_entries = sub_archive.infolist()
                                for sub_entry in sub_entries:
                                    with sub_archive.open(sub_entry) as sub_file:
                                        img_file_name = f'{data_file}/{sub_entry.filename}'
                                        yield (img_file_name)

                        else:
                            # Should be image file.
                            img_file_name = entry.filename
                            yield (img_file_name)
    else:
        # Should be image file
        yield data_file

def get_file_paths(data_dir):

    # Placeholder for file in data_dir
    dir_list = []

    if not os.path.isfile(data_dir):
        # A normal directory
        for root, dirs, files in os.walk(data_dir):
            for file in files:
                dir_list.append(os.path.join(root, file))
    else:
        # A single file (could be a zip archive or image)
        dir_list = [data_dir]

    # Placeholder for file_path for files found
    file_path_list = []

    for file in dir_list:
        for file_path in fetch_file_paths(file):
            print (f'File: {file_path}')
            file_path_list.append(file_path)
    
    return file_path_list

get_file_paths(folder_path)
# Out:
# File: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg
# File: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg
# File: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg
# File: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg
# File: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg
# File: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg
# File: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg
# File: testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg
# File: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg
# File: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg
# File: testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg
# File: testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png
# File: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg
# File: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png
# File: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg
# File: testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg
# File: testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg
# File: testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png
# File: testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png
# File: testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg
# File: testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg
# File: testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png
# File: testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg
# File: testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png
# ['testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_ee_d1_f0eed195037b8fc2135a44ceb5ed2044.jpg',
#  'testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_71_f0f071d89545fb378150180d9257f306.jpg',
#  'testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f0_b4_f0f0b4f3f1d172a789589915fc4ad212.jpg',
#  'testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f5_b8_f0f5b8c94169977da31274f36b0aa703.jpg',
#  'testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_f6_08_f0f608ca8c7e5bcd0b3ffc565442d74f.jpg',
#  'testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fc_b5_f0fcb58b15c19afc5fc1f33ff2acda74.jpg',
#  'testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f0_fe_b3_f0feb3bf4202a15d69629e9ddd990809.jpg',
#  'testdata/not-pixel-art-real-photo/https___i.pinimg.com_originals_f1_00_9d_f1009d0dd411b52e827bbcd0d30080fa.jpg',
#  'testdata/not-pixel-art/https___i.pinimg.com_originals_f3_bb_e6_f3bbe6fa7aa5b9c925bb36954dc8786c.jpg',
#  'testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c2_a5_f3c2a5e03978093319ba184fb54e009e.jpg',
#  'testdata/not-pixel-art/https___i.pinimg.com_originals_f3_c3_c2_f3c3c2c7fb350b03dccc99a66d3a3a86.jpg',
#  'testdata/not-pixel-art/https___i.pinimg.com_originals_f4_d6_97_f4d697934ac2656bcc9bba971262829c.png',
#  'testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a3_b8_f6a3b85a6877bd06e0197063a720bcf6.jpg',
#  'testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_11_f6a411b2046bad82ca94402131e14e67.png',
#  'testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_db_f6a4db94afa72c01847cb2c8733d2155.jpg',
#  'testdata/not-pixel-art/https___i.pinimg.com_originals_f6_a4_fb_f6a4fbf097fd103d2f8c923016cf1368.jpg',
#  'testdata/other-training/https___i.pinimg.com_originals_00_00_57_000057f3850f9771864630687c4bdf26.jpg',
#  'testdata/other-training/https___i.pinimg.com_originals_00_00_e7_0000e7f96134fbd9ea78cca6986be247.png',
#  'testdata/other-training/https___i.pinimg.com_originals_00_0a_a5_000aa58efa428d0bdf580388a8403a49.png',
#  'testdata/other-training/https___i.pinimg.com_originals_00_0b_2d_000b2d8351f053664b41ca1024b41b1f.jpg',
#  'testdata/other-validation/https___i.pinimg.com_originals_00_78_74_0078749a6a33588ea8995080904d96fc.jpg',
#  'testdata/other-validation/https___i.pinimg.com_originals_00_79_2c_00792c0d83d415a707bdacee51646d9e.png',
#  'testdata/other-validation/https___i.pinimg.com_originals_00_79_32_007932f2045adf1d7b785d53021ccd0f.jpg',
#  'testdata/other-validation/https___i.pinimg.com_originals_00_81_01_0081018e59980d9b1a5cbe03dd9557cf.png']

# %% [markdown]
# #### Get List of File Hash_ID from Tag Cache Based on List of Models or Specific Model

# %%
import json
from clip_cache.cache_tag import TagCache

# Specify path to tag cache file
tag_cache_path = './output/tag_cache.sqlite'

# Output placeholder
model_tag_cache_pair = {}

try:
    # Create tag cache object
    tag_cache = TagCache()
    # Create model api object
    model_api=ModelApi()

    # Getting models
    models_dict = model_api.get_models_dict()
    '''
    Example stucture of models_dict
    {<model_name>: 
        {'classifier' : <model object>,
        'model_type' : <model type string>,
        'train_start_time' : <traing start time datetime object>
        'tag' : <tag string>
        }
    }
    '''

    # Get tags from models_dict
    for model in models_dict:
        # Get list of images (hash_IDs) based on each model's tag name
        hash_ids = tag_cache.get_hash_by_tag(db_path = tag_cache_path, tag = models_dict[model]['tag'])
        # Append list of hash IDs to the result dict
        model_tag_cache_pair[model] = hash_ids
    
    # Output
    print(json.dumps(model_tag_cache_pair, indent=2))

except Exception as e:
    print (f'[ERROR] {e}: Getting data from tag cache failed')
# Out:
# [ERROR] no such table: tag_cache: Getting tag failed, tag cache database does not exist or might be in use!
# [ERROR] no such table: tag_cache: Getting tag failed, tag cache database does not exist or might be in use!
# [ERROR] no such table: tag_cache: Getting tag failed, tag cache database does not exist or might be in use!
# [ERROR] no such table: tag_cache: Getting tag failed, tag cache database does not exist or might be in use!
# [ERROR] no such table: tag_cache: Getting tag failed, tag cache database does not exist or might be in use!
# [ERROR] no such table: tag_cache: Getting tag failed, tag cache database does not exist or might be in use!
# {
#   "model-ovr-logistic-regression-tag-not-pixel-art-real-photo": null,
#   "model-torch-logistic-regression-tag-not-pixel-art": null,
#   "model-ovr-logistic-regression-tag-not-pixel-art": null,
#   "model-ovr-svm-tag-not-pixel-art-real-photo": null,
#   "model-torch-logistic-regression-tag-not-pixel-art-real-photo": null,
#   "model-ovr-svm-tag-not-pixel-art": null
# }
